# %% [markdown]
# # Visualising the data

# %% [markdown]
# In this notebook, we will guide you through visualising the data you downloaded through the API in the form of graphs. In the process we introduce ```pandas```, a very popular data processing library. Entire books have been written on the  ```pandas``` library, and there is an extensive online [documentation](https://pandas.pydata.org/docs/); in this notebook, we will restrict ourselves to the minimum required to use the library as a wrapper for ```matplotlib```, a lower-level data visualisation library.
#
# Both ```pandas``` and ```matplotlib``` are installed on the QMUL JupyterHub server, and they are likely to be part of any major Python distribution, so the following ```import``` statements should just work. Installation instructions for [pandas](https://pandas.pydata.org/docs/getting_started/install.html) and [matplotlib](https://matplotlib.org/users/installing.html) are available online.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import json

# %%
# an iPython  "magic" that enables the embedding of matplotlib output
# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## Time series data

# %% [markdown]
# We start by loading the data from the JSON file in which we saved it. Reading a JSON file in Python is not any more difficult than writing it:

# %%
with open("admissions.json", "rt") as INFILE:
    admissions=json.load(INFILE)
with open("cases.json", "rt") as INFILE:
    cases=json.load(INFILE)
with open("deaths.json", "rt") as INFILE:
    deaths=json.load(INFILE)

# %% [markdown]
# ### Wrangling the data
#
# Whatever your query, the data is unlikely to come in a form that's amenable to be plotted directly; some wrangling, munging, or other bit of cool data science jargon is required. Our aim is to extract values for the *x* axis of our plot (in this case the dates). These will become the *index* of a ```DataFrame```, of which the *columns* will contain the data proper. You can, for the moment, think of a ```DataFrame``` as the Python equivalent of an Excel spreadsheet.

# %%
cases[:5]
# Out:
# [{'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_casesByDay',
#   'metric_group': 'cases',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2020,
#   'month': 1,
#   'epiweek': 5,
#   'date': '2020-01-30',
#   'metric_value': 1.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_casesByDay',
#   'metric_group': 'cases',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2020,
#   'month': 1,
#   'epiweek': 5,
#   'date': '2020-01-31',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_casesByDay',
#   'metric_group': 'cases',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2020,
#   'month': 2,
#   'epiweek': 5,
#   'date': '2020-02-01',
#   'metric_value': 0.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_casesByDay',
#   'metric_group': 'cases',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2020,
#   'month': 2,
#   'epiweek': 5,
#   'date': '2020-02-02',
#   'metric_value': 1.0,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_casesByDay',
#   'metric_group': 'cases',
#   'stratum': 'default',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2020,
#   'month': 2,
#   'epiweek': 6,
#   'date': '2020-02-03',
#   'metric_value': 18.0,
#   'in_reporting_delay_period': False}]

# %% [markdown]
# As we can see, the data consists of a list of dictionaries; actual data is stored in the inner dictionaries under the ```date``` and ```metric_value``` keys. Let us start by retrieving those values and bringing everything together into a dictionary with the dates as keys, and inner dictionaries with the three metrics as values:

# %%
data={}
for dataset in [admissions, cases, deaths]:
    for entry in dataset:
        date=entry['date']
        metric=entry['metric']
        value=entry['metric_value']
        if date not in data:
            data[date]={}
        data[date][metric]=value

# %%
data
# Out:
# {'2020-08-01': {'COVID-19_healthcare_admissionByDay': 50.0,
#   'COVID-19_cases_casesByDay': 508.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2020-08-02': {'COVID-19_healthcare_admissionByDay': 57.0,
#   'COVID-19_cases_casesByDay': 518.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2020-08-03': {'COVID-19_healthcare_admissionByDay': 74.0,
#   'COVID-19_cases_casesByDay': 963.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2020-08-04': {'COVID-19_healthcare_admissionByDay': 58.0,
#   'COVID-19_cases_casesByDay': 965.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2020-08-05': {'COVID-19_healthcare_admissionByDay': 60.0,
#   'COVID-19_cases_casesByDay': 973.0,
#   'COVID-19_deaths_ONSByDay': 7.0},
#  '2020-08-06': {'COVID-19_healthcare_admissionByDay': 52.0,
#   'COVID-19_cases_casesByDay': 1005.0,
#   'COVID-19_deaths_ONSByDay': 17.0},
#  '2020-08-07': {'COVID-19_healthcare_admissionByDay': 60.0,
#   'COVID-19_cases_casesByDay': 892.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2020-08-08': {'COVID-19_healthcare_admissionByDay': 78.0,
#   'COVID-19_cases_casesByDay': 648.0,
#   'COVID-19_deaths_ONSByDay': 18.0},
#  '2020-08-09': {'COVID-19_healthcare_admissionByDay': 53.0,
#   'COVID-19_cases_casesByDay': 569.0,
#   'COVID-19_deaths_ONSByDay': 18.0},
#  '2020-08-10': {'COVID-19_healthcare_admissionByDay': 50.0,
#   'COVID-19_cases_casesByDay': 1375.0,
#   'COVID-19_deaths_ONSByDay': 23.0},
#  '2020-08-11': {'COVID-19_healthcare_admissionByDay': 63.0,
#   'COVID-19_cases_casesByDay': 1247.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2020-08-12': {'COVID-19_healthcare_admissionByDay': 51.0,
#   'COVID-19_cases_casesByDay': 1126.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2020-08-13': {'COVID-19_healthcare_admissionByDay': 60.0,
#   'COVID-19_cases_casesByDay': 1036.0,
#   'COVID-19_deaths_ONSByDay': 18.0},
#  '2020-08-14': {'COVID-19_healthcare_admissionByDay': 55.0,
#   'COVID-19_cases_casesByDay': 1059.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2020-08-15': {'COVID-19_healthcare_admissionByDay': 38.0,
#   'COVID-19_cases_casesByDay': 656.0,
#   'COVID-19_deaths_ONSByDay': 21.0},
#  '2020-08-16': {'COVID-19_healthcare_admissionByDay': 39.0,
#   'COVID-19_cases_casesByDay': 535.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2020-08-17': {'COVID-19_healthcare_admissionByDay': 46.0,
#   'COVID-19_cases_casesByDay': 1158.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2020-08-18': {'COVID-19_healthcare_admissionByDay': 56.0,
#   'COVID-19_cases_casesByDay': 955.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2020-08-19': {'COVID-19_healthcare_admissionByDay': 58.0,
#   'COVID-19_cases_casesByDay': 1106.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2020-08-20': {'COVID-19_healthcare_admissionByDay': 45.0,
#   'COVID-19_cases_casesByDay': 1254.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2020-08-21': {'COVID-19_healthcare_admissionByDay': 49.0,
#   'COVID-19_cases_casesByDay': 1031.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2020-08-22': {'COVID-19_healthcare_admissionByDay': 25.0,
#   'COVID-19_cases_casesByDay': 732.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2020-08-23': {'COVID-19_healthcare_admissionByDay': 44.0,
#   'COVID-19_cases_casesByDay': 704.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2020-08-24': {'COVID-19_healthcare_admissionByDay': 41.0,
#   'COVID-19_cases_casesByDay': 1156.0,
#   'COVID-19_deaths_ONSByDay': 8.0},
#  '2020-08-25': {'COVID-19_healthcare_admissionByDay': 60.0,
#   'COVID-19_cases_casesByDay': 1085.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2020-08-26': {'COVID-19_healthcare_admissionByDay': 52.0,
#   'COVID-19_cases_casesByDay': 1181.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2020-08-27': {'COVID-19_healthcare_admissionByDay': 69.0,
#   'COVID-19_cases_casesByDay': 1356.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2020-08-28': {'COVID-19_healthcare_admissionByDay': 44.0,
#   'COVID-19_cases_casesByDay': 1395.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2020-08-29': {'COVID-19_healthcare_admissionByDay': 52.0,
#   'COVID-19_cases_casesByDay': 1051.0,
#   'COVID-19_deaths_ONSByDay': 8.0},
#  '2020-08-30': {'COVID-19_healthcare_admissionByDay': 38.0,
#   'COVID-19_cases_casesByDay': 987.0,
#   'COVID-19_deaths_ONSByDay': 8.0},
#  '2020-08-31': {'COVID-19_healthcare_admissionByDay': 52.0,
#   'COVID-19_cases_casesByDay': 1279.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2020-09-01': {'COVID-19_healthcare_admissionByDay': 58.0,
#   'COVID-19_cases_casesByDay': 1962.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2020-09-02': {'COVID-19_healthcare_admissionByDay': 79.0,
#   'COVID-19_cases_casesByDay': 2696.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2020-09-03': {'COVID-19_healthcare_admissionByDay': 69.0,
#   'COVID-19_cases_casesByDay': 2716.0,
#   'COVID-19_deaths_ONSByDay': 6.0},
#  '2020-09-04': {'COVID-19_healthcare_admissionByDay': 67.0,
#   'COVID-19_cases_casesByDay': 2637.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2020-09-05': {'COVID-19_healthcare_admissionByDay': 94.0,
#   'COVID-19_cases_casesByDay': 2200.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2020-09-06': {'COVID-19_healthcare_admissionByDay': 85.0,
#   'COVID-19_cases_casesByDay': 2079.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2020-09-07': {'COVID-19_healthcare_admissionByDay': 84.0,
#   'COVID-19_cases_casesByDay': 3530.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2020-09-08': {'COVID-19_healthcare_admissionByDay': 99.0,
#   'COVID-19_cases_casesByDay': 3071.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2020-09-09': {'COVID-19_healthcare_admissionByDay': 136.0,
#   'COVID-19_cases_casesByDay': 2893.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2020-09-10': {'COVID-19_healthcare_admissionByDay': 143.0,
#   'COVID-19_cases_casesByDay': 3143.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2020-09-11': {'COVID-19_healthcare_admissionByDay': 135.0,
#   'COVID-19_cases_casesByDay': 2893.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2020-09-12': {'COVID-19_healthcare_admissionByDay': 143.0,
#   'COVID-19_cases_casesByDay': 2224.0,
#   'COVID-19_deaths_ONSByDay': 21.0},
#  '2020-09-13': {'COVID-19_healthcare_admissionByDay': 153.0,
#   'COVID-19_cases_casesByDay': 1722.0,
#   'COVID-19_deaths_ONSByDay': 18.0},
#  '2020-09-14': {'COVID-19_healthcare_admissionByDay': 172.0,
#   'COVID-19_cases_casesByDay': 2941.0,
#   'COVID-19_deaths_ONSByDay': 17.0},
#  '2020-09-15': {'COVID-19_healthcare_admissionByDay': 194.0,
#   'COVID-19_cases_casesByDay': 3057.0,
#   'COVID-19_deaths_ONSByDay': 22.0},
#  '2020-09-16': {'COVID-19_healthcare_admissionByDay': 183.0,
#   'COVID-19_cases_casesByDay': 3778.0,
#   'COVID-19_deaths_ONSByDay': 25.0},
#  '2020-09-17': {'COVID-19_healthcare_admissionByDay': 199.0,
#   'COVID-19_cases_casesByDay': 3979.0,
#   'COVID-19_deaths_ONSByDay': 34.0},
#  '2020-09-18': {'COVID-19_healthcare_admissionByDay': 205.0,
#   'COVID-19_cases_casesByDay': 4290.0,
#   'COVID-19_deaths_ONSByDay': 25.0},
#  '2020-09-19': {'COVID-19_healthcare_admissionByDay': 204.0,
#   'COVID-19_cases_casesByDay': 4215.0,
#   'COVID-19_deaths_ONSByDay': 22.0},
#  '2020-09-20': {'COVID-19_healthcare_admissionByDay': 237.0,
#   'COVID-19_cases_casesByDay': 4652.0,
#   'COVID-19_deaths_ONSByDay': 34.0},
#  '2020-09-21': {'COVID-19_healthcare_admissionByDay': 275.0,
#   'COVID-19_cases_casesByDay': 4727.0,
#   'COVID-19_deaths_ONSByDay': 26.0},
#  '2020-09-22': {'COVID-19_healthcare_admissionByDay': 268.0,
#   'COVID-19_cases_casesByDay': 5400.0,
#   'COVID-19_deaths_ONSByDay': 32.0},
#  '2020-09-23': {'COVID-19_healthcare_admissionByDay': 314.0,
#   'COVID-19_cases_casesByDay': 5934.0,
#   'COVID-19_deaths_ONSByDay': 52.0},
#  '2020-09-24': {'COVID-19_healthcare_admissionByDay': 288.0,
#   'COVID-19_cases_casesByDay': 6361.0,
#   'COVID-19_deaths_ONSByDay': 33.0},
#  '2020-09-25': {'COVID-19_healthcare_admissionByDay': 274.0,
#   'COVID-19_cases_casesByDay': 6105.0,
#   'COVID-19_deaths_ONSByDay': 35.0},
#  '2020-09-26': {'COVID-19_healthcare_admissionByDay': 245.0,
#   'COVID-19_cases_casesByDay': 5704.0,
#   'COVID-19_deaths_ONSByDay': 43.0},
#  '2020-09-27': {'COVID-19_healthcare_admissionByDay': 241.0,
#   'COVID-19_cases_casesByDay': 6084.0,
#   'COVID-19_deaths_ONSByDay': 49.0},
#  '2020-09-28': {'COVID-19_healthcare_admissionByDay': 308.0,
#   'COVID-19_cases_casesByDay': 8641.0,
#   'COVID-19_deaths_ONSByDay': 47.0},
#  '2020-09-29': {'COVID-19_healthcare_admissionByDay': 310.0,
#   'COVID-19_cases_casesByDay': 8832.0,
#   'COVID-19_deaths_ONSByDay': 42.0},
#  '2020-09-30': {'COVID-19_healthcare_admissionByDay': 328.0,
#   'COVID-19_cases_casesByDay': 10663.0,
#   'COVID-19_deaths_ONSByDay': 53.0},
#  '2020-10-01': {'COVID-19_healthcare_admissionByDay': 368.0,
#   'COVID-19_cases_casesByDay': 11444.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2020-10-02': {'COVID-19_healthcare_admissionByDay': 371.0,
#   'COVID-19_cases_casesByDay': 11719.0,
#   'COVID-19_deaths_ONSByDay': 69.0},
#  '2020-10-03': {'COVID-19_healthcare_admissionByDay': 386.0,
#   'COVID-19_cases_casesByDay': 9820.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2020-10-04': {'COVID-19_healthcare_admissionByDay': 478.0,
#   'COVID-19_cases_casesByDay': 9966.0,
#   'COVID-19_deaths_ONSByDay': 55.0},
#  '2020-10-05': {'COVID-19_healthcare_admissionByDay': 472.0,
#   'COVID-19_cases_casesByDay': 14218.0,
#   'COVID-19_deaths_ONSByDay': 54.0},
#  '2020-10-06': {'COVID-19_healthcare_admissionByDay': 524.0,
#   'COVID-19_cases_casesByDay': 14458.0,
#   'COVID-19_deaths_ONSByDay': 69.0},
#  '2020-10-07': {'COVID-19_healthcare_admissionByDay': 491.0,
#   'COVID-19_cases_casesByDay': 15418.0,
#   'COVID-19_deaths_ONSByDay': 88.0},
#  '2020-10-08': {'COVID-19_healthcare_admissionByDay': 513.0,
#   'COVID-19_cases_casesByDay': 15452.0,
#   'COVID-19_deaths_ONSByDay': 80.0},
#  '2020-10-09': {'COVID-19_healthcare_admissionByDay': 544.0,
#   'COVID-19_cases_casesByDay': 13158.0,
#   'COVID-19_deaths_ONSByDay': 82.0},
#  '2020-10-10': {'COVID-19_healthcare_admissionByDay': 515.0,
#   'COVID-19_cases_casesByDay': 10301.0,
#   'COVID-19_deaths_ONSByDay': 87.0},
#  '2020-10-11': {'COVID-19_healthcare_admissionByDay': 628.0,
#   'COVID-19_cases_casesByDay': 9781.0,
#   'COVID-19_deaths_ONSByDay': 106.0},
#  '2020-10-12': {'COVID-19_healthcare_admissionByDay': 664.0,
#   'COVID-19_cases_casesByDay': 16420.0,
#   'COVID-19_deaths_ONSByDay': 94.0},
#  '2020-10-13': {'COVID-19_healthcare_admissionByDay': 764.0,
#   'COVID-19_cases_casesByDay': 15660.0,
#   'COVID-19_deaths_ONSByDay': 94.0},
#  '2020-10-14': {'COVID-19_healthcare_admissionByDay': 706.0,
#   'COVID-19_cases_casesByDay': 16644.0,
#   'COVID-19_deaths_ONSByDay': 104.0},
#  '2020-10-15': {'COVID-19_healthcare_admissionByDay': 792.0,
#   'COVID-19_cases_casesByDay': 15428.0,
#   'COVID-19_deaths_ONSByDay': 124.0},
#  '2020-10-16': {'COVID-19_healthcare_admissionByDay': 632.0,
#   'COVID-19_cases_casesByDay': 14761.0,
#   'COVID-19_deaths_ONSByDay': 125.0},
#  '2020-10-17': {'COVID-19_healthcare_admissionByDay': 785.0,
#   'COVID-19_cases_casesByDay': 12488.0,
#   'COVID-19_deaths_ONSByDay': 168.0},
#  '2020-10-18': {'COVID-19_healthcare_admissionByDay': 870.0,
#   'COVID-19_cases_casesByDay': 11982.0,
#   'COVID-19_deaths_ONSByDay': 124.0},
#  '2020-10-19': {'COVID-19_healthcare_admissionByDay': 861.0,
#   'COVID-19_cases_casesByDay': 22369.0,
#   'COVID-19_deaths_ONSByDay': 155.0},
#  '2020-10-20': {'COVID-19_healthcare_admissionByDay': 925.0,
#   'COVID-19_cases_casesByDay': 21638.0,
#   'COVID-19_deaths_ONSByDay': 177.0},
#  '2020-10-21': {'COVID-19_healthcare_admissionByDay': 997.0,
#   'COVID-19_cases_casesByDay': 21762.0,
#   'COVID-19_deaths_ONSByDay': 196.0},
#  '2020-10-22': {'COVID-19_healthcare_admissionByDay': 987.0,
#   'COVID-19_cases_casesByDay': 19866.0,
#   'COVID-19_deaths_ONSByDay': 186.0},
#  '2020-10-23': {'COVID-19_healthcare_admissionByDay': 997.0,
#   'COVID-19_cases_casesByDay': 18359.0,
#   'COVID-19_deaths_ONSByDay': 183.0},
#  '2020-10-24': {'COVID-19_healthcare_admissionByDay': 990.0,
#   'COVID-19_cases_casesByDay': 13713.0,
#   'COVID-19_deaths_ONSByDay': 174.0},
#  '2020-10-25': {'COVID-19_healthcare_admissionByDay': 1186.0,
#   'COVID-19_cases_casesByDay': 13353.0,
#   'COVID-19_deaths_ONSByDay': 207.0},
#  '2020-10-26': {'COVID-19_healthcare_admissionByDay': 1279.0,
#   'COVID-19_cases_casesByDay': 23033.0,
#   'COVID-19_deaths_ONSByDay': 218.0},
#  '2020-10-27': {'COVID-19_healthcare_admissionByDay': 1190.0,
#   'COVID-19_cases_casesByDay': 20762.0,
#   'COVID-19_deaths_ONSByDay': 226.0},
#  '2020-10-28': {'COVID-19_healthcare_admissionByDay': 1239.0,
#   'COVID-19_cases_casesByDay': 20548.0,
#   'COVID-19_deaths_ONSByDay': 228.0},
#  '2020-10-29': {'COVID-19_healthcare_admissionByDay': 1345.0,
#   'COVID-19_cases_casesByDay': 20256.0,
#   'COVID-19_deaths_ONSByDay': 253.0},
#  '2020-10-30': {'COVID-19_healthcare_admissionByDay': 1109.0,
#   'COVID-19_cases_casesByDay': 19899.0,
#   'COVID-19_deaths_ONSByDay': 284.0},
#  '2020-10-31': {'COVID-19_healthcare_admissionByDay': 1240.0,
#   'COVID-19_cases_casesByDay': 14565.0,
#   'COVID-19_deaths_ONSByDay': 277.0},
#  '2020-11-01': {'COVID-19_healthcare_admissionByDay': 1280.0,
#   'COVID-19_cases_casesByDay': 13611.0,
#   'COVID-19_deaths_ONSByDay': 283.0},
#  '2020-11-02': {'COVID-19_healthcare_admissionByDay': 1331.0,
#   'COVID-19_cases_casesByDay': 28394.0,
#   'COVID-19_deaths_ONSByDay': 279.0},
#  '2020-11-03': {'COVID-19_healthcare_admissionByDay': 1246.0,
#   'COVID-19_cases_casesByDay': 22690.0,
#   'COVID-19_deaths_ONSByDay': 304.0},
#  '2020-11-04': {'COVID-19_healthcare_admissionByDay': 1382.0,
#   'COVID-19_cases_casesByDay': 21053.0,
#   'COVID-19_deaths_ONSByDay': 283.0},
#  '2020-11-05': {'COVID-19_healthcare_admissionByDay': 1346.0,
#   'COVID-19_cases_casesByDay': 21206.0,
#   'COVID-19_deaths_ONSByDay': 300.0},
#  '2020-11-06': {'COVID-19_healthcare_admissionByDay': 1182.0,
#   'COVID-19_cases_casesByDay': 21179.0,
#   'COVID-19_deaths_ONSByDay': 339.0},
#  '2020-11-07': {'COVID-19_healthcare_admissionByDay': 1319.0,
#   'COVID-19_cases_casesByDay': 16888.0,
#   'COVID-19_deaths_ONSByDay': 348.0},
#  '2020-11-08': {'COVID-19_healthcare_admissionByDay': 1488.0,
#   'COVID-19_cases_casesByDay': 18272.0,
#   'COVID-19_deaths_ONSByDay': 347.0},
#  '2020-11-09': {'COVID-19_healthcare_admissionByDay': 1551.0,
#   'COVID-19_cases_casesByDay': 28562.0,
#   'COVID-19_deaths_ONSByDay': 404.0},
#  '2020-11-10': {'COVID-19_healthcare_admissionByDay': 1592.0,
#   'COVID-19_cases_casesByDay': 24836.0,
#   'COVID-19_deaths_ONSByDay': 329.0},
#  '2020-11-11': {'COVID-19_healthcare_admissionByDay': 1711.0,
#   'COVID-19_cases_casesByDay': 25064.0,
#   'COVID-19_deaths_ONSByDay': 317.0},
#  '2020-11-12': {'COVID-19_healthcare_admissionByDay': 1666.0,
#   'COVID-19_cases_casesByDay': 22320.0,
#   'COVID-19_deaths_ONSByDay': 357.0},
#  '2020-11-13': {'COVID-19_healthcare_admissionByDay': 1433.0,
#   'COVID-19_cases_casesByDay': 22009.0,
#   'COVID-19_deaths_ONSByDay': 352.0},
#  '2020-11-14': {'COVID-19_healthcare_admissionByDay': 1388.0,
#   'COVID-19_cases_casesByDay': 16290.0,
#   'COVID-19_deaths_ONSByDay': 367.0},
#  '2020-11-15': {'COVID-19_healthcare_admissionByDay': 1467.0,
#   'COVID-19_cases_casesByDay': 14430.0,
#   'COVID-19_deaths_ONSByDay': 375.0},
#  '2020-11-16': {'COVID-19_healthcare_admissionByDay': 1560.0,
#   'COVID-19_cases_casesByDay': 24147.0,
#   'COVID-19_deaths_ONSByDay': 362.0},
#  '2020-11-17': {'COVID-19_healthcare_admissionByDay': 1491.0,
#   'COVID-19_cases_casesByDay': 20675.0,
#   'COVID-19_deaths_ONSByDay': 378.0},
#  '2020-11-18': {'COVID-19_healthcare_admissionByDay': 1571.0,
#   'COVID-19_cases_casesByDay': 18545.0,
#   'COVID-19_deaths_ONSByDay': 444.0},
#  '2020-11-19': {'COVID-19_healthcare_admissionByDay': 1484.0,
#   'COVID-19_cases_casesByDay': 15797.0,
#   'COVID-19_deaths_ONSByDay': 407.0},
#  '2020-11-20': {'COVID-19_healthcare_admissionByDay': 1316.0,
#   'COVID-19_cases_casesByDay': 14960.0,
#   'COVID-19_deaths_ONSByDay': 407.0},
#  '2020-11-21': {'COVID-19_healthcare_admissionByDay': 1255.0,
#   'COVID-19_cases_casesByDay': 10806.0,
#   'COVID-19_deaths_ONSByDay': 413.0},
#  '2020-11-22': {'COVID-19_healthcare_admissionByDay': 1333.0,
#   'COVID-19_cases_casesByDay': 10216.0,
#   'COVID-19_deaths_ONSByDay': 420.0},
#  '2020-11-23': {'COVID-19_healthcare_admissionByDay': 1385.0,
#   'COVID-19_cases_casesByDay': 16472.0,
#   'COVID-19_deaths_ONSByDay': 429.0},
#  '2020-11-24': {'COVID-19_healthcare_admissionByDay': 1277.0,
#   'COVID-19_cases_casesByDay': 14267.0,
#   'COVID-19_deaths_ONSByDay': 423.0},
#  '2020-11-25': {'COVID-19_healthcare_admissionByDay': 1415.0,
#   'COVID-19_cases_casesByDay': 14153.0,
#   'COVID-19_deaths_ONSByDay': 436.0},
#  '2020-11-26': {'COVID-19_healthcare_admissionByDay': 1198.0,
#   'COVID-19_cases_casesByDay': 12458.0,
#   'COVID-19_deaths_ONSByDay': 380.0},
#  '2020-11-27': {'COVID-19_healthcare_admissionByDay': 1055.0,
#   'COVID-19_cases_casesByDay': 12459.0,
#   'COVID-19_deaths_ONSByDay': 387.0},
#  '2020-11-28': {'COVID-19_healthcare_admissionByDay': 1065.0,
#   'COVID-19_cases_casesByDay': 9348.0,
#   'COVID-19_deaths_ONSByDay': 389.0},
#  '2020-11-29': {'COVID-19_healthcare_admissionByDay': 1215.0,
#   'COVID-19_cases_casesByDay': 9067.0,
#   'COVID-19_deaths_ONSByDay': 423.0},
#  '2020-11-30': {'COVID-19_healthcare_admissionByDay': 1216.0,
#   'COVID-19_cases_casesByDay': 15228.0,
#   'COVID-19_deaths_ONSByDay': 385.0},
#  '2020-12-01': {'COVID-19_healthcare_admissionByDay': 1271.0,
#   'COVID-19_cases_casesByDay': 13732.0,
#   'COVID-19_deaths_ONSByDay': 359.0},
#  '2020-12-02': {'COVID-19_healthcare_admissionByDay': 1262.0,
#   'COVID-19_cases_casesByDay': 13661.0,
#   'COVID-19_deaths_ONSByDay': 348.0},
#  '2020-12-03': {'COVID-19_healthcare_admissionByDay': 1337.0,
#   'COVID-19_cases_casesByDay': 12761.0,
#   'COVID-19_deaths_ONSByDay': 410.0},
#  '2020-12-04': {'COVID-19_healthcare_admissionByDay': 1248.0,
#   'COVID-19_cases_casesByDay': 13065.0,
#   'COVID-19_deaths_ONSByDay': 420.0},
#  '2020-12-05': {'COVID-19_healthcare_admissionByDay': 1186.0,
#   'COVID-19_cases_casesByDay': 10302.0,
#   'COVID-19_deaths_ONSByDay': 345.0},
#  '2020-12-06': {'COVID-19_healthcare_admissionByDay': 1311.0,
#   'COVID-19_cases_casesByDay': 11036.0,
#   'COVID-19_deaths_ONSByDay': 363.0},
#  '2020-12-07': {'COVID-19_healthcare_admissionByDay': 1466.0,
#   'COVID-19_cases_casesByDay': 17662.0,
#   'COVID-19_deaths_ONSByDay': 379.0},
#  '2020-12-08': {'COVID-19_healthcare_admissionByDay': 1528.0,
#   'COVID-19_cases_casesByDay': 16937.0,
#   'COVID-19_deaths_ONSByDay': 398.0},
#  '2020-12-09': {'COVID-19_healthcare_admissionByDay': 1550.0,
#   'COVID-19_cases_casesByDay': 17744.0,
#   'COVID-19_deaths_ONSByDay': 381.0},
#  '2020-12-10': {'COVID-19_healthcare_admissionByDay': 1524.0,
#   'COVID-19_cases_casesByDay': 18850.0,
#   'COVID-19_deaths_ONSByDay': 407.0},
#  '2020-12-11': {'COVID-19_healthcare_admissionByDay': 1450.0,
#   'COVID-19_cases_casesByDay': 20177.0,
#   'COVID-19_deaths_ONSByDay': 424.0},
#  '2020-12-12': {'COVID-19_healthcare_admissionByDay': 1587.0,
#   'COVID-19_cases_casesByDay': 16268.0,
#   'COVID-19_deaths_ONSByDay': 411.0},
#  '2020-12-13': {'COVID-19_healthcare_admissionByDay': 1581.0,
#   'COVID-19_cases_casesByDay': 18409.0,
#   'COVID-19_deaths_ONSByDay': 410.0},
#  '2020-12-14': {'COVID-19_healthcare_admissionByDay': 1746.0,
#   'COVID-19_cases_casesByDay': 30019.0,
#   'COVID-19_deaths_ONSByDay': 422.0},
#  '2020-12-15': {'COVID-19_healthcare_admissionByDay': 1730.0,
#   'COVID-19_cases_casesByDay': 29652.0,
#   'COVID-19_deaths_ONSByDay': 408.0},
#  '2020-12-16': {'COVID-19_healthcare_admissionByDay': 1796.0,
#   'COVID-19_cases_casesByDay': 30648.0,
#   'COVID-19_deaths_ONSByDay': 386.0},
#  '2020-12-17': {'COVID-19_healthcare_admissionByDay': 1873.0,
#   'COVID-19_cases_casesByDay': 30160.0,
#   'COVID-19_deaths_ONSByDay': 463.0},
#  '2020-12-18': {'COVID-19_healthcare_admissionByDay': 1672.0,
#   'COVID-19_cases_casesByDay': 32426.0,
#   'COVID-19_deaths_ONSByDay': 478.0},
#  '2020-12-19': {'COVID-19_healthcare_admissionByDay': 1812.0,
#   'COVID-19_cases_casesByDay': 22195.0,
#   'COVID-19_deaths_ONSByDay': 457.0},
#  '2020-12-20': {'COVID-19_healthcare_admissionByDay': 1976.0,
#   'COVID-19_cases_casesByDay': 29556.0,
#   'COVID-19_deaths_ONSByDay': 455.0},
#  '2020-12-21': {'COVID-19_healthcare_admissionByDay': 2115.0,
#   'COVID-19_cases_casesByDay': 43446.0,
#   'COVID-19_deaths_ONSByDay': 506.0},
#  '2020-12-22': {'COVID-19_healthcare_admissionByDay': 2203.0,
#   'COVID-19_cases_casesByDay': 41741.0,
#   'COVID-19_deaths_ONSByDay': 539.0},
#  '2020-12-23': {'COVID-19_healthcare_admissionByDay': 1980.0,
#   'COVID-19_cases_casesByDay': 38382.0,
#   'COVID-19_deaths_ONSByDay': 519.0},
#  '2020-12-24': {'COVID-19_healthcare_admissionByDay': 1795.0,
#   'COVID-19_cases_casesByDay': 29287.0,
#   'COVID-19_deaths_ONSByDay': 503.0},
#  '2020-12-25': {'COVID-19_healthcare_admissionByDay': 1952.0,
#   'COVID-19_cases_casesByDay': 12926.0,
#   'COVID-19_deaths_ONSByDay': 558.0},
#  '2020-12-26': {'COVID-19_healthcare_admissionByDay': 2298.0,
#   'COVID-19_cases_casesByDay': 37462.0,
#   'COVID-19_deaths_ONSByDay': 593.0},
#  '2020-12-27': {'COVID-19_healthcare_admissionByDay': 2572.0,
#   'COVID-19_cases_casesByDay': 43250.0,
#   'COVID-19_deaths_ONSByDay': 612.0},
#  '2020-12-28': {'COVID-19_healthcare_admissionByDay': 2795.0,
#   'COVID-19_cases_casesByDay': 40845.0,
#   'COVID-19_deaths_ONSByDay': 615.0},
#  '2020-12-29': {'COVID-19_healthcare_admissionByDay': 2886.0,
#   'COVID-19_cases_casesByDay': 74058.0,
#   'COVID-19_deaths_ONSByDay': 614.0},
#  '2020-12-30': {'COVID-19_healthcare_admissionByDay': 2861.0,
#   'COVID-19_cases_casesByDay': 64243.0,
#   'COVID-19_deaths_ONSByDay': 655.0},
#  '2020-12-31': {'COVID-19_healthcare_admissionByDay': 2536.0,
#   'COVID-19_cases_casesByDay': 47824.0,
#   'COVID-19_deaths_ONSByDay': 701.0},
#  '2021-01-01': {'COVID-19_healthcare_admissionByDay': 3010.0,
#   'COVID-19_cases_casesByDay': 28879.0,
#   'COVID-19_deaths_ONSByDay': 689.0},
#  '2021-01-02': {'COVID-19_healthcare_admissionByDay': 3145.0,
#   'COVID-19_cases_casesByDay': 55428.0,
#   'COVID-19_deaths_ONSByDay': 726.0},
#  '2021-01-03': {'COVID-19_healthcare_admissionByDay': 3351.0,
#   'COVID-19_cases_casesByDay': 50664.0,
#   'COVID-19_deaths_ONSByDay': 684.0},
#  '2021-01-04': {'COVID-19_healthcare_admissionByDay': 3587.0,
#   'COVID-19_cases_casesByDay': 70920.0,
#   'COVID-19_deaths_ONSByDay': 790.0},
#  '2021-01-05': {'COVID-19_healthcare_admissionByDay': 3697.0,
#   'COVID-19_cases_casesByDay': 59601.0,
#   'COVID-19_deaths_ONSByDay': 856.0},
#  '2021-01-06': {'COVID-19_healthcare_admissionByDay': 3967.0,
#   'COVID-19_cases_casesByDay': 52752.0,
#   'COVID-19_deaths_ONSByDay': 882.0},
#  '2021-01-07': {'COVID-19_healthcare_admissionByDay': 3849.0,
#   'COVID-19_cases_casesByDay': 48132.0,
#   'COVID-19_deaths_ONSByDay': 918.0},
#  '2021-01-08': {'COVID-19_healthcare_admissionByDay': 3549.0,
#   'COVID-19_cases_casesByDay': 43494.0,
#   'COVID-19_deaths_ONSByDay': 922.0},
#  '2021-01-09': {'COVID-19_healthcare_admissionByDay': 3718.0,
#   'COVID-19_cases_casesByDay': 36420.0,
#   'COVID-19_deaths_ONSByDay': 976.0},
#  '2021-01-10': {'COVID-19_healthcare_admissionByDay': 3571.0,
#   'COVID-19_cases_casesByDay': 33749.0,
#   'COVID-19_deaths_ONSByDay': 1030.0},
#  '2021-01-11': {'COVID-19_healthcare_admissionByDay': 3894.0,
#   'COVID-19_cases_casesByDay': 53519.0,
#   'COVID-19_deaths_ONSByDay': 1076.0},
#  '2021-01-12': {'COVID-19_healthcare_admissionByDay': 4134.0,
#   'COVID-19_cases_casesByDay': 45968.0,
#   'COVID-19_deaths_ONSByDay': 1173.0},
#  '2021-01-13': {'COVID-19_healthcare_admissionByDay': 3840.0,
#   'COVID-19_cases_casesByDay': 42302.0,
#   'COVID-19_deaths_ONSByDay': 1161.0},
#  '2021-01-14': {'COVID-19_healthcare_admissionByDay': 3678.0,
#   'COVID-19_cases_casesByDay': 39660.0,
#   'COVID-19_deaths_ONSByDay': 1167.0},
#  '2021-01-15': {'COVID-19_healthcare_admissionByDay': 3295.0,
#   'COVID-19_cases_casesByDay': 37878.0,
#   'COVID-19_deaths_ONSByDay': 1162.0},
#  '2021-01-16': {'COVID-19_healthcare_admissionByDay': 3569.0,
#   'COVID-19_cases_casesByDay': 28413.0,
#   'COVID-19_deaths_ONSByDay': 1241.0},
#  '2021-01-17': {'COVID-19_healthcare_admissionByDay': 3424.0,
#   'COVID-19_cases_casesByDay': 26976.0,
#   'COVID-19_deaths_ONSByDay': 1229.0},
#  '2021-01-18': {'COVID-19_healthcare_admissionByDay': 3711.0,
#   'COVID-19_cases_casesByDay': 41936.0,
#   'COVID-19_deaths_ONSByDay': 1242.0},
#  '2021-01-19': {'COVID-19_healthcare_admissionByDay': 3768.0,
#   'COVID-19_cases_casesByDay': 37054.0,
#   'COVID-19_deaths_ONSByDay': 1328.0},
#  '2021-01-20': {'COVID-19_healthcare_admissionByDay': 3679.0,
#   'COVID-19_cases_casesByDay': 32678.0,
#   'COVID-19_deaths_ONSByDay': 1237.0},
#  '2021-01-21': {'COVID-19_healthcare_admissionByDay': 3237.0,
#   'COVID-19_cases_casesByDay': 29632.0,
#   'COVID-19_deaths_ONSByDay': 1204.0},
#  '2021-01-22': {'COVID-19_healthcare_admissionByDay': 3016.0,
#   'COVID-19_cases_casesByDay': 27741.0,
#   'COVID-19_deaths_ONSByDay': 1189.0},
#  '2021-01-23': {'COVID-19_healthcare_admissionByDay': 2780.0,
#   'COVID-19_cases_casesByDay': 20425.0,
#   'COVID-19_deaths_ONSByDay': 1148.0},
#  '2021-01-24': {'COVID-19_healthcare_admissionByDay': 2824.0,
#   'COVID-19_cases_casesByDay': 15883.0,
#   'COVID-19_deaths_ONSByDay': 1086.0},
#  '2021-01-25': {'COVID-19_healthcare_admissionByDay': 2648.0,
#   'COVID-19_cases_casesByDay': 27972.0,
#   'COVID-19_deaths_ONSByDay': 1150.0},
#  '2021-01-26': {'COVID-19_healthcare_admissionByDay': 2799.0,
#   'COVID-19_cases_casesByDay': 25209.0,
#   'COVID-19_deaths_ONSByDay': 1046.0},
#  '2021-01-27': {'COVID-19_healthcare_admissionByDay': 2742.0,
#   'COVID-19_cases_casesByDay': 23899.0,
#   'COVID-19_deaths_ONSByDay': 1108.0},
#  '2021-01-28': {'COVID-19_healthcare_admissionByDay': 2719.0,
#   'COVID-19_cases_casesByDay': 22523.0,
#   'COVID-19_deaths_ONSByDay': 1110.0},
#  '2021-01-29': {'COVID-19_healthcare_admissionByDay': 2379.0,
#   'COVID-19_cases_casesByDay': 20363.0,
#   'COVID-19_deaths_ONSByDay': 1008.0},
#  '2021-01-30': {'COVID-19_healthcare_admissionByDay': 2193.0,
#   'COVID-19_cases_casesByDay': 15524.0,
#   'COVID-19_deaths_ONSByDay': 924.0},
#  '2021-01-31': {'COVID-19_healthcare_admissionByDay': 2183.0,
#   'COVID-19_cases_casesByDay': 14138.0,
#   'COVID-19_deaths_ONSByDay': 899.0},
#  '2021-02-01': {'COVID-19_healthcare_admissionByDay': 2347.0,
#   'COVID-19_cases_casesByDay': 20764.0,
#   'COVID-19_deaths_ONSByDay': 893.0},
#  '2021-02-02': {'COVID-19_healthcare_admissionByDay': 2222.0,
#   'COVID-19_cases_casesByDay': 18193.0,
#   'COVID-19_deaths_ONSByDay': 854.0},
#  '2021-02-03': {'COVID-19_healthcare_admissionByDay': 2096.0,
#   'COVID-19_cases_casesByDay': 17948.0,
#   'COVID-19_deaths_ONSByDay': 872.0},
#  '2021-02-04': {'COVID-19_healthcare_admissionByDay': 1907.0,
#   'COVID-19_cases_casesByDay': 16717.0,
#   'COVID-19_deaths_ONSByDay': 735.0},
#  '2021-02-05': {'COVID-19_healthcare_admissionByDay': 1757.0,
#   'COVID-19_cases_casesByDay': 14461.0,
#   'COVID-19_deaths_ONSByDay': 771.0},
#  '2021-02-06': {'COVID-19_healthcare_admissionByDay': 1679.0,
#   'COVID-19_cases_casesByDay': 10951.0,
#   'COVID-19_deaths_ONSByDay': 686.0},
#  '2021-02-07': {'COVID-19_healthcare_admissionByDay': 1675.0,
#   'COVID-19_cases_casesByDay': 10458.0,
#   'COVID-19_deaths_ONSByDay': 665.0},
#  '2021-02-08': {'COVID-19_healthcare_admissionByDay': 1739.0,
#   'COVID-19_cases_casesByDay': 14370.0,
#   'COVID-19_deaths_ONSByDay': 702.0},
#  '2021-02-09': {'COVID-19_healthcare_admissionByDay': 1531.0,
#   'COVID-19_cases_casesByDay': 12696.0,
#   'COVID-19_deaths_ONSByDay': 628.0},
#  '2021-02-10': {'COVID-19_healthcare_admissionByDay': 1535.0,
#   'COVID-19_cases_casesByDay': 12272.0,
#   'COVID-19_deaths_ONSByDay': 629.0},
#  '2021-02-11': {'COVID-19_healthcare_admissionByDay': 1440.0,
#   'COVID-19_cases_casesByDay': 11637.0,
#   'COVID-19_deaths_ONSByDay': 590.0},
#  '2021-02-12': {'COVID-19_healthcare_admissionByDay': 1318.0,
#   'COVID-19_cases_casesByDay': 10986.0,
#   'COVID-19_deaths_ONSByDay': 546.0},
#  '2021-02-13': {'COVID-19_healthcare_admissionByDay': 1240.0,
#   'COVID-19_cases_casesByDay': 8025.0,
#   'COVID-19_deaths_ONSByDay': 512.0},
#  '2021-02-14': {'COVID-19_healthcare_admissionByDay': 1364.0,
#   'COVID-19_cases_casesByDay': 7781.0,
#   'COVID-19_deaths_ONSByDay': 520.0},
#  '2021-02-15': {'COVID-19_healthcare_admissionByDay': 1322.0,
#   'COVID-19_cases_casesByDay': 12953.0,
#   'COVID-19_deaths_ONSByDay': 549.0},
#  '2021-02-16': {'COVID-19_healthcare_admissionByDay': 1311.0,
#   'COVID-19_cases_casesByDay': 11268.0,
#   'COVID-19_deaths_ONSByDay': 501.0},
#  '2021-02-17': {'COVID-19_healthcare_admissionByDay': 1233.0,
#   'COVID-19_cases_casesByDay': 10419.0,
#   'COVID-19_deaths_ONSByDay': 438.0},
#  '2021-02-18': {'COVID-19_healthcare_admissionByDay': 1149.0,
#   'COVID-19_cases_casesByDay': 10303.0,
#   'COVID-19_deaths_ONSByDay': 454.0},
#  '2021-02-19': {'COVID-19_healthcare_admissionByDay': 1068.0,
#   'COVID-19_cases_casesByDay': 9246.0,
#   'COVID-19_deaths_ONSByDay': 390.0},
#  '2021-02-20': {'COVID-19_healthcare_admissionByDay': 904.0,
#   'COVID-19_cases_casesByDay': 7161.0,
#   'COVID-19_deaths_ONSByDay': 388.0},
#  '2021-02-21': {'COVID-19_healthcare_admissionByDay': 1008.0,
#   'COVID-19_cases_casesByDay': 7033.0,
#   'COVID-19_deaths_ONSByDay': 355.0},
#  '2021-02-22': {'COVID-19_healthcare_admissionByDay': 980.0,
#   'COVID-19_cases_casesByDay': 10279.0,
#   'COVID-19_deaths_ONSByDay': 325.0},
#  '2021-02-23': {'COVID-19_healthcare_admissionByDay': 976.0,
#   'COVID-19_cases_casesByDay': 8536.0,
#   'COVID-19_deaths_ONSByDay': 336.0},
#  '2021-02-24': {'COVID-19_healthcare_admissionByDay': 874.0,
#   'COVID-19_cases_casesByDay': 7620.0,
#   'COVID-19_deaths_ONSByDay': 317.0},
#  '2021-02-25': {'COVID-19_healthcare_admissionByDay': 832.0,
#   'COVID-19_cases_casesByDay': 6933.0,
#   'COVID-19_deaths_ONSByDay': 308.0},
#  '2021-02-26': {'COVID-19_healthcare_admissionByDay': 718.0,
#   'COVID-19_cases_casesByDay': 5883.0,
#   'COVID-19_deaths_ONSByDay': 262.0},
#  '2021-02-27': {'COVID-19_healthcare_admissionByDay': 624.0,
#   'COVID-19_cases_casesByDay': 4254.0,
#   'COVID-19_deaths_ONSByDay': 265.0},
#  '2021-02-28': {'COVID-19_healthcare_admissionByDay': 662.0,
#   'COVID-19_cases_casesByDay': 4112.0,
#   'COVID-19_deaths_ONSByDay': 257.0},
#  '2021-03-01': {'COVID-19_healthcare_admissionByDay': 704.0,
#   'COVID-19_cases_casesByDay': 6215.0,
#   'COVID-19_deaths_ONSByDay': 254.0},
#  '2021-03-02': {'COVID-19_healthcare_admissionByDay': 683.0,
#   'COVID-19_cases_casesByDay': 5950.0,
#   'COVID-19_deaths_ONSByDay': 210.0},
#  '2021-03-03': {'COVID-19_healthcare_admissionByDay': 607.0,
#   'COVID-19_cases_casesByDay': 5305.0,
#   'COVID-19_deaths_ONSByDay': 188.0},
#  '2021-03-04': {'COVID-19_healthcare_admissionByDay': 596.0,
#   'COVID-19_cases_casesByDay': 5011.0,
#   'COVID-19_deaths_ONSByDay': 204.0},
#  '2021-03-05': {'COVID-19_healthcare_admissionByDay': 487.0,
#   'COVID-19_cases_casesByDay': 4728.0,
#   'COVID-19_deaths_ONSByDay': 203.0},
#  '2021-03-06': {'COVID-19_healthcare_admissionByDay': 528.0,
#   'COVID-19_cases_casesByDay': 3832.0,
#   'COVID-19_deaths_ONSByDay': 178.0},
#  '2021-03-07': {'COVID-19_healthcare_admissionByDay': 461.0,
#   'COVID-19_cases_casesByDay': 3677.0,
#   'COVID-19_deaths_ONSByDay': 175.0},
#  '2021-03-08': {'COVID-19_healthcare_admissionByDay': 501.0,
#   'COVID-19_cases_casesByDay': 5818.0,
#   'COVID-19_deaths_ONSByDay': 165.0},
#  '2021-03-09': {'COVID-19_healthcare_admissionByDay': 483.0,
#   'COVID-19_cases_casesByDay': 5488.0,
#   'COVID-19_deaths_ONSByDay': 160.0},
#  '2021-03-10': {'COVID-19_healthcare_admissionByDay': 494.0,
#   'COVID-19_cases_casesByDay': 5222.0,
#   'COVID-19_deaths_ONSByDay': 136.0},
#  '2021-03-11': {'COVID-19_healthcare_admissionByDay': 449.0,
#   'COVID-19_cases_casesByDay': 4848.0,
#   'COVID-19_deaths_ONSByDay': 152.0},
#  '2021-03-12': {'COVID-19_healthcare_admissionByDay': 386.0,
#   'COVID-19_cases_casesByDay': 4767.0,
#   'COVID-19_deaths_ONSByDay': 117.0},
#  '2021-03-13': {'COVID-19_healthcare_admissionByDay': 385.0,
#   'COVID-19_cases_casesByDay': 3592.0,
#   'COVID-19_deaths_ONSByDay': 123.0},
#  '2021-03-14': {'COVID-19_healthcare_admissionByDay': 357.0,
#   'COVID-19_cases_casesByDay': 3707.0,
#   'COVID-19_deaths_ONSByDay': 115.0},
#  '2021-03-15': {'COVID-19_healthcare_admissionByDay': 431.0,
#   'COVID-19_cases_casesByDay': 5643.0,
#   'COVID-19_deaths_ONSByDay': 122.0},
#  '2021-03-16': {'COVID-19_healthcare_admissionByDay': 364.0,
#   'COVID-19_cases_casesByDay': 4933.0,
#   'COVID-19_deaths_ONSByDay': 94.0},
#  '2021-03-17': {'COVID-19_healthcare_admissionByDay': 343.0,
#   'COVID-19_cases_casesByDay': 5047.0,
#   'COVID-19_deaths_ONSByDay': 104.0},
#  '2021-03-18': {'COVID-19_healthcare_admissionByDay': 351.0,
#   'COVID-19_cases_casesByDay': 4689.0,
#   'COVID-19_deaths_ONSByDay': 85.0},
#  '2021-03-19': {'COVID-19_healthcare_admissionByDay': 283.0,
#   'COVID-19_cases_casesByDay': 4333.0,
#   'COVID-19_deaths_ONSByDay': 82.0},
#  '2021-03-20': {'COVID-19_healthcare_admissionByDay': 287.0,
#   'COVID-19_cases_casesByDay': 3514.0,
#   'COVID-19_deaths_ONSByDay': 89.0},
#  '2021-03-21': {'COVID-19_healthcare_admissionByDay': 279.0,
#   'COVID-19_cases_casesByDay': 4679.0,
#   'COVID-19_deaths_ONSByDay': 109.0},
#  '2021-03-22': {'COVID-19_healthcare_admissionByDay': 294.0,
#   'COVID-19_cases_casesByDay': 5400.0,
#   'COVID-19_deaths_ONSByDay': 89.0},
#  '2021-03-23': {'COVID-19_healthcare_admissionByDay': 295.0,
#   'COVID-19_cases_casesByDay': 4566.0,
#   'COVID-19_deaths_ONSByDay': 83.0},
#  '2021-03-24': {'COVID-19_healthcare_admissionByDay': 277.0,
#   'COVID-19_cases_casesByDay': 5321.0,
#   'COVID-19_deaths_ONSByDay': 58.0},
#  '2021-03-25': {'COVID-19_healthcare_admissionByDay': 288.0,
#   'COVID-19_cases_casesByDay': 4674.0,
#   'COVID-19_deaths_ONSByDay': 68.0},
#  '2021-03-26': {'COVID-19_healthcare_admissionByDay': 245.0,
#   'COVID-19_cases_casesByDay': 3803.0,
#   'COVID-19_deaths_ONSByDay': 61.0},
#  '2021-03-27': {'COVID-19_healthcare_admissionByDay': 217.0,
#   'COVID-19_cases_casesByDay': 3136.0,
#   'COVID-19_deaths_ONSByDay': 55.0},
#  '2021-03-28': {'COVID-19_healthcare_admissionByDay': 221.0,
#   'COVID-19_cases_casesByDay': 4477.0,
#   'COVID-19_deaths_ONSByDay': 43.0},
#  '2021-03-29': {'COVID-19_healthcare_admissionByDay': 206.0,
#   'COVID-19_cases_casesByDay': 3422.0,
#   'COVID-19_deaths_ONSByDay': 58.0},
#  '2021-03-30': {'COVID-19_healthcare_admissionByDay': 217.0,
#   'COVID-19_cases_casesByDay': 3135.0,
#   'COVID-19_deaths_ONSByDay': 50.0},
#  '2021-03-31': {'COVID-19_healthcare_admissionByDay': 225.0,
#   'COVID-19_cases_casesByDay': 3340.0,
#   'COVID-19_deaths_ONSByDay': 64.0},
#  '2021-04-01': {'COVID-19_healthcare_admissionByDay': 180.0,
#   'COVID-19_cases_casesByDay': 3067.0,
#   'COVID-19_deaths_ONSByDay': 54.0},
#  '2021-04-02': {'COVID-19_healthcare_admissionByDay': 178.0,
#   'COVID-19_cases_casesByDay': 2248.0,
#   'COVID-19_deaths_ONSByDay': 38.0},
#  '2021-04-03': {'COVID-19_healthcare_admissionByDay': 179.0,
#   'COVID-19_cases_casesByDay': 2121.0,
#   'COVID-19_deaths_ONSByDay': 34.0},
#  '2021-04-04': {'COVID-19_healthcare_admissionByDay': 156.0,
#   'COVID-19_cases_casesByDay': 2042.0,
#   'COVID-19_deaths_ONSByDay': 51.0},
#  '2021-04-05': {'COVID-19_healthcare_admissionByDay': 188.0,
#   'COVID-19_cases_casesByDay': 2314.0,
#   'COVID-19_deaths_ONSByDay': 35.0},
#  '2021-04-06': {'COVID-19_healthcare_admissionByDay': 183.0,
#   'COVID-19_cases_casesByDay': 2756.0,
#   'COVID-19_deaths_ONSByDay': 37.0},
#  '2021-04-07': {'COVID-19_healthcare_admissionByDay': 189.0,
#   'COVID-19_cases_casesByDay': 2752.0,
#   'COVID-19_deaths_ONSByDay': 38.0},
#  '2021-04-08': {'COVID-19_healthcare_admissionByDay': 167.0,
#   'COVID-19_cases_casesByDay': 2651.0,
#   'COVID-19_deaths_ONSByDay': 52.0},
#  '2021-04-09': {'COVID-19_healthcare_admissionByDay': 167.0,
#   'COVID-19_cases_casesByDay': 2482.0,
#   'COVID-19_deaths_ONSByDay': 32.0},
#  '2021-04-10': {'COVID-19_healthcare_admissionByDay': 151.0,
#   'COVID-19_cases_casesByDay': 2009.0,
#   'COVID-19_deaths_ONSByDay': 36.0},
#  '2021-04-11': {'COVID-19_healthcare_admissionByDay': 175.0,
#   'COVID-19_cases_casesByDay': 2020.0,
#   'COVID-19_deaths_ONSByDay': 34.0},
#  '2021-04-12': {'COVID-19_healthcare_admissionByDay': 173.0,
#   'COVID-19_cases_casesByDay': 2399.0,
#   'COVID-19_deaths_ONSByDay': 36.0},
#  '2021-04-13': {'COVID-19_healthcare_admissionByDay': 153.0,
#   'COVID-19_cases_casesByDay': 2060.0,
#   'COVID-19_deaths_ONSByDay': 37.0},
#  '2021-04-14': {'COVID-19_healthcare_admissionByDay': 156.0,
#   'COVID-19_cases_casesByDay': 2068.0,
#   'COVID-19_deaths_ONSByDay': 26.0},
#  '2021-04-15': {'COVID-19_healthcare_admissionByDay': 127.0,
#   'COVID-19_cases_casesByDay': 1959.0,
#   'COVID-19_deaths_ONSByDay': 37.0},
#  '2021-04-16': {'COVID-19_healthcare_admissionByDay': 118.0,
#   'COVID-19_cases_casesByDay': 1963.0,
#   'COVID-19_deaths_ONSByDay': 28.0},
#  '2021-04-17': {'COVID-19_healthcare_admissionByDay': 135.0,
#   'COVID-19_cases_casesByDay': 1398.0,
#   'COVID-19_deaths_ONSByDay': 36.0},
#  '2021-04-18': {'COVID-19_healthcare_admissionByDay': 112.0,
#   'COVID-19_cases_casesByDay': 2281.0,
#   'COVID-19_deaths_ONSByDay': 27.0},
#  '2021-04-19': {'COVID-19_healthcare_admissionByDay': 138.0,
#   'COVID-19_cases_casesByDay': 2268.0,
#   'COVID-19_deaths_ONSByDay': 17.0},
#  '2021-04-20': {'COVID-19_healthcare_admissionByDay': 98.0,
#   'COVID-19_cases_casesByDay': 2112.0,
#   'COVID-19_deaths_ONSByDay': 30.0},
#  '2021-04-21': {'COVID-19_healthcare_admissionByDay': 126.0,
#   'COVID-19_cases_casesByDay': 2298.0,
#   'COVID-19_deaths_ONSByDay': 26.0},
#  '2021-04-22': {'COVID-19_healthcare_admissionByDay': 92.0,
#   'COVID-19_cases_casesByDay': 2032.0,
#   'COVID-19_deaths_ONSByDay': 28.0},
#  '2021-04-23': {'COVID-19_healthcare_admissionByDay': 124.0,
#   'COVID-19_cases_casesByDay': 1701.0,
#   'COVID-19_deaths_ONSByDay': 23.0},
#  '2021-04-24': {'COVID-19_healthcare_admissionByDay': 99.0,
#   'COVID-19_cases_casesByDay': 1300.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2021-04-25': {'COVID-19_healthcare_admissionByDay': 107.0,
#   'COVID-19_cases_casesByDay': 1897.0,
#   'COVID-19_deaths_ONSByDay': 22.0},
#  '2021-04-26': {'COVID-19_healthcare_admissionByDay': 108.0,
#   'COVID-19_cases_casesByDay': 2267.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2021-04-27': {'COVID-19_healthcare_admissionByDay': 128.0,
#   'COVID-19_cases_casesByDay': 1809.0,
#   'COVID-19_deaths_ONSByDay': 23.0},
#  '2021-04-28': {'COVID-19_healthcare_admissionByDay': 89.0,
#   'COVID-19_cases_casesByDay': 2153.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2021-04-29': {'COVID-19_healthcare_admissionByDay': 80.0,
#   'COVID-19_cases_casesByDay': 1901.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2021-04-30': {'COVID-19_healthcare_admissionByDay': 82.0,
#   'COVID-19_cases_casesByDay': 1528.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2021-05-01': {'COVID-19_healthcare_admissionByDay': 68.0,
#   'COVID-19_cases_casesByDay': 1211.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-05-02': {'COVID-19_healthcare_admissionByDay': 92.0,
#   'COVID-19_cases_casesByDay': 1305.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2021-05-03': {'COVID-19_healthcare_admissionByDay': 98.0,
#   'COVID-19_cases_casesByDay': 1806.0,
#   'COVID-19_deaths_ONSByDay': 17.0},
#  '2021-05-04': {'COVID-19_healthcare_admissionByDay': 76.0,
#   'COVID-19_cases_casesByDay': 2200.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-05-05': {'COVID-19_healthcare_admissionByDay': 96.0,
#   'COVID-19_cases_casesByDay': 2203.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2021-05-06': {'COVID-19_healthcare_admissionByDay': 88.0,
#   'COVID-19_cases_casesByDay': 1967.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-05-07': {'COVID-19_healthcare_admissionByDay': 77.0,
#   'COVID-19_cases_casesByDay': 1657.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2021-05-08': {'COVID-19_healthcare_admissionByDay': 80.0,
#   'COVID-19_cases_casesByDay': 1301.0,
#   'COVID-19_deaths_ONSByDay': 17.0},
#  '2021-05-09': {'COVID-19_healthcare_admissionByDay': 76.0,
#   'COVID-19_cases_casesByDay': 1985.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2021-05-10': {'COVID-19_healthcare_admissionByDay': 76.0,
#   'COVID-19_cases_casesByDay': 2325.0,
#   'COVID-19_deaths_ONSByDay': 7.0},
#  '2021-05-11': {'COVID-19_healthcare_admissionByDay': 79.0,
#   'COVID-19_cases_casesByDay': 1872.0,
#   'COVID-19_deaths_ONSByDay': 19.0},
#  '2021-05-12': {'COVID-19_healthcare_admissionByDay': 93.0,
#   'COVID-19_cases_casesByDay': 1869.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-05-13': {'COVID-19_healthcare_admissionByDay': 74.0,
#   'COVID-19_cases_casesByDay': 1737.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2021-05-14': {'COVID-19_healthcare_admissionByDay': 72.0,
#   'COVID-19_cases_casesByDay': 1540.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2021-05-15': {'COVID-19_healthcare_admissionByDay': 70.0,
#   'COVID-19_cases_casesByDay': 1306.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-05-16': {'COVID-19_healthcare_admissionByDay': 59.0,
#   'COVID-19_cases_casesByDay': 1587.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2021-05-17': {'COVID-19_healthcare_admissionByDay': 74.0,
#   'COVID-19_cases_casesByDay': 2341.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2021-05-18': {'COVID-19_healthcare_admissionByDay': 90.0,
#   'COVID-19_cases_casesByDay': 2241.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2021-05-19': {'COVID-19_healthcare_admissionByDay': 93.0,
#   'COVID-19_cases_casesByDay': 2261.0,
#   'COVID-19_deaths_ONSByDay': 3.0},
#  '2021-05-20': {'COVID-19_healthcare_admissionByDay': 98.0,
#   'COVID-19_cases_casesByDay': 2000.0,
#   'COVID-19_deaths_ONSByDay': 6.0},
#  '2021-05-21': {'COVID-19_healthcare_admissionByDay': 85.0,
#   'COVID-19_cases_casesByDay': 1872.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2021-05-22': {'COVID-19_healthcare_admissionByDay': 75.0,
#   'COVID-19_cases_casesByDay': 1606.0,
#   'COVID-19_deaths_ONSByDay': 3.0},
#  '2021-05-23': {'COVID-19_healthcare_admissionByDay': 77.0,
#   'COVID-19_cases_casesByDay': 1918.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-05-24': {'COVID-19_healthcare_admissionByDay': 98.0,
#   'COVID-19_cases_casesByDay': 2750.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-05-25': {'COVID-19_healthcare_admissionByDay': 88.0,
#   'COVID-19_cases_casesByDay': 2797.0,
#   'COVID-19_deaths_ONSByDay': 8.0},
#  '2021-05-26': {'COVID-19_healthcare_admissionByDay': 95.0,
#   'COVID-19_cases_casesByDay': 3179.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2021-05-27': {'COVID-19_healthcare_admissionByDay': 83.0,
#   'COVID-19_cases_casesByDay': 3075.0,
#   'COVID-19_deaths_ONSByDay': 8.0},
#  '2021-05-28': {'COVID-19_healthcare_admissionByDay': 92.0,
#   'COVID-19_cases_casesByDay': 2929.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2021-05-29': {'COVID-19_healthcare_admissionByDay': 69.0,
#   'COVID-19_cases_casesByDay': 2462.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2021-05-30': {'COVID-19_healthcare_admissionByDay': 80.0,
#   'COVID-19_cases_casesByDay': 2598.0,
#   'COVID-19_deaths_ONSByDay': 8.0},
#  '2021-05-31': {'COVID-19_healthcare_admissionByDay': 98.0,
#   'COVID-19_cases_casesByDay': 3170.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2021-06-01': {'COVID-19_healthcare_admissionByDay': 115.0,
#   'COVID-19_cases_casesByDay': 4515.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2021-06-02': {'COVID-19_healthcare_admissionByDay': 101.0,
#   'COVID-19_cases_casesByDay': 5039.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2021-06-03': {'COVID-19_healthcare_admissionByDay': 93.0,
#   'COVID-19_cases_casesByDay': 5131.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-06-04': {'COVID-19_healthcare_admissionByDay': 96.0,
#   'COVID-19_cases_casesByDay': 4886.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-06-05': {'COVID-19_healthcare_admissionByDay': 96.0,
#   'COVID-19_cases_casesByDay': 3964.0,
#   'COVID-19_deaths_ONSByDay': 5.0},
#  '2021-06-06': {'COVID-19_healthcare_admissionByDay': 121.0,
#   'COVID-19_cases_casesByDay': 4730.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2021-06-07': {'COVID-19_healthcare_admissionByDay': 131.0,
#   'COVID-19_cases_casesByDay': 6791.0,
#   'COVID-19_deaths_ONSByDay': 5.0},
#  '2021-06-08': {'COVID-19_healthcare_admissionByDay': 147.0,
#   'COVID-19_cases_casesByDay': 6627.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-06-09': {'COVID-19_healthcare_admissionByDay': 158.0,
#   'COVID-19_cases_casesByDay': 6919.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-06-10': {'COVID-19_healthcare_admissionByDay': 162.0,
#   'COVID-19_cases_casesByDay': 6718.0,
#   'COVID-19_deaths_ONSByDay': 16.0},
#  '2021-06-11': {'COVID-19_healthcare_admissionByDay': 144.0,
#   'COVID-19_cases_casesByDay': 6510.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2021-06-12': {'COVID-19_healthcare_admissionByDay': 137.0,
#   'COVID-19_cases_casesByDay': 5422.0,
#   'COVID-19_deaths_ONSByDay': 11.0},
#  '2021-06-13': {'COVID-19_healthcare_admissionByDay': 187.0,
#   'COVID-19_cases_casesByDay': 6075.0,
#   'COVID-19_deaths_ONSByDay': 9.0},
#  '2021-06-14': {'COVID-19_healthcare_admissionByDay': 185.0,
#   'COVID-19_cases_casesByDay': 8941.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2021-06-15': {'COVID-19_healthcare_admissionByDay': 188.0,
#   'COVID-19_cases_casesByDay': 9153.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2021-06-16': {'COVID-19_healthcare_admissionByDay': 177.0,
#   'COVID-19_cases_casesByDay': 9411.0,
#   'COVID-19_deaths_ONSByDay': 15.0},
#  '2021-06-17': {'COVID-19_healthcare_admissionByDay': 202.0,
#   'COVID-19_cases_casesByDay': 9523.0,
#   'COVID-19_deaths_ONSByDay': 7.0},
#  '2021-06-18': {'COVID-19_healthcare_admissionByDay': 185.0,
#   'COVID-19_cases_casesByDay': 8770.0,
#   'COVID-19_deaths_ONSByDay': 14.0},
#  '2021-06-19': {'COVID-19_healthcare_admissionByDay': 178.0,
#   'COVID-19_cases_casesByDay': 7127.0,
#   'COVID-19_deaths_ONSByDay': 17.0},
#  '2021-06-20': {'COVID-19_healthcare_admissionByDay': 171.0,
#   'COVID-19_cases_casesByDay': 8203.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2021-06-21': {'COVID-19_healthcare_admissionByDay': 181.0,
#   'COVID-19_cases_casesByDay': 12707.0,
#   'COVID-19_deaths_ONSByDay': 12.0},
#  '2021-06-22': {'COVID-19_healthcare_admissionByDay': 182.0,
#   'COVID-19_cases_casesByDay': 13563.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-06-23': {'COVID-19_healthcare_admissionByDay': 214.0,
#   'COVID-19_cases_casesByDay': 14806.0,
#   'COVID-19_deaths_ONSByDay': 6.0},
#  '2021-06-24': {'COVID-19_healthcare_admissionByDay': 194.0,
#   'COVID-19_cases_casesByDay': 15084.0,
#   'COVID-19_deaths_ONSByDay': 23.0},
#  '2021-06-25': {'COVID-19_healthcare_admissionByDay': 206.0,
#   'COVID-19_cases_casesByDay': 14901.0,
#   'COVID-19_deaths_ONSByDay': 21.0},
#  '2021-06-26': {'COVID-19_healthcare_admissionByDay': 223.0,
#   'COVID-19_cases_casesByDay': 13486.0,
#   'COVID-19_deaths_ONSByDay': 10.0},
#  '2021-06-27': {'COVID-19_healthcare_admissionByDay': 226.0,
#   'COVID-19_cases_casesByDay': 15407.0,
#   'COVID-19_deaths_ONSByDay': 20.0},
#  '2021-06-28': {'COVID-19_healthcare_admissionByDay': 244.0,
#   'COVID-19_cases_casesByDay': 23511.0,
#   'COVID-19_deaths_ONSByDay': 13.0},
#  '2021-06-29': {'COVID-19_healthcare_admissionByDay': 283.0,
#   'COVID-19_cases_casesByDay': 23250.0,
#   'COVID-19_deaths_ONSByDay': 21.0},
#  '2021-06-30': {'COVID-19_healthcare_admissionByDay': 331.0,
#   'COVID-19_cases_casesByDay': 23941.0,
#   'COVID-19_deaths_ONSByDay': 23.0},
#  '2021-07-01': {'COVID-19_healthcare_admissionByDay': 295.0,
#   'COVID-19_cases_casesByDay': 24267.0,
#   'COVID-19_deaths_ONSByDay': 25.0},
#  '2021-07-02': {'COVID-19_healthcare_admissionByDay': 307.0,
#   'COVID-19_cases_casesByDay': 22287.0,
#   'COVID-19_deaths_ONSByDay': 26.0},
#  '2021-07-03': {'COVID-19_healthcare_admissionByDay': 323.0,
#   'COVID-19_cases_casesByDay': 20638.0,
#   'COVID-19_deaths_ONSByDay': 27.0},
#  '2021-07-04': {'COVID-19_healthcare_admissionByDay': 390.0,
#   'COVID-19_cases_casesByDay': 21806.0,
#   'COVID-19_deaths_ONSByDay': 24.0},
#  '2021-07-05': {'COVID-19_healthcare_admissionByDay': 416.0,
#   'COVID-19_cases_casesByDay': 30215.0,
#   'COVID-19_deaths_ONSByDay': 21.0},
#  '2021-07-06': {'COVID-19_healthcare_admissionByDay': 458.0,
#   'COVID-19_cases_casesByDay': 31626.0,
#   'COVID-19_deaths_ONSByDay': 22.0},
#  '2021-07-07': {'COVID-19_healthcare_admissionByDay': 461.0,
#   'COVID-19_cases_casesByDay': 34274.0,
#   'COVID-19_deaths_ONSByDay': 28.0},
#  '2021-07-08': {'COVID-19_healthcare_admissionByDay': 488.0,
#   'COVID-19_cases_casesByDay': 29929.0,
#   'COVID-19_deaths_ONSByDay': 30.0},
#  '2021-07-09': {'COVID-19_healthcare_admissionByDay': 451.0,
#   'COVID-19_cases_casesByDay': 29050.0,
#   'COVID-19_deaths_ONSByDay': 43.0},
#  '2021-07-10': {'COVID-19_healthcare_admissionByDay': 442.0,
#   'COVID-19_cases_casesByDay': 25411.0,
#   'COVID-19_deaths_ONSByDay': 34.0},
#  '2021-07-11': {'COVID-19_healthcare_admissionByDay': 502.0,
#   'COVID-19_cases_casesByDay': 27418.0,
#   'COVID-19_deaths_ONSByDay': 28.0},
#  '2021-07-12': {'COVID-19_healthcare_admissionByDay': 610.0,
#   'COVID-19_cases_casesByDay': 40477.0,
#   'COVID-19_deaths_ONSByDay': 34.0},
#  '2021-07-13': {'COVID-19_healthcare_admissionByDay': 621.0,
#   'COVID-19_cases_casesByDay': 43247.0,
#   'COVID-19_deaths_ONSByDay': 40.0},
#  '2021-07-14': {'COVID-19_healthcare_admissionByDay': 636.0,
#   'COVID-19_cases_casesByDay': 50320.0,
# ...
#   'COVID-19_cases_casesByDay': 3339.0,
#   'COVID-19_deaths_ONSByDay': 111.0},
#  '2023-01-02': {'COVID-19_healthcare_admissionByDay': 916.0,
#   'COVID-19_cases_casesByDay': 4636.0,
#   'COVID-19_deaths_ONSByDay': 108.0},
#  '2023-01-03': {'COVID-19_healthcare_admissionByDay': 992.0,
#   'COVID-19_cases_casesByDay': 5740.0,
#   'COVID-19_deaths_ONSByDay': 114.0},
#  '2023-01-04': {'COVID-19_healthcare_admissionByDay': 922.0,
#   'COVID-19_cases_casesByDay': 5013.0,
#   'COVID-19_deaths_ONSByDay': 117.0},
#  '2023-01-05': {'COVID-19_healthcare_admissionByDay': 899.0,
#   'COVID-19_cases_casesByDay': 4170.0,
#   'COVID-19_deaths_ONSByDay': 115.0},
#  '2023-01-06': {'COVID-19_healthcare_admissionByDay': 705.0,
#   'COVID-19_cases_casesByDay': 3415.0,
#   'COVID-19_deaths_ONSByDay': 88.0},
#  '2023-01-07': {'COVID-19_healthcare_admissionByDay': 628.0,
#   'COVID-19_cases_casesByDay': 2416.0,
#   'COVID-19_deaths_ONSByDay': 99.0},
#  '2023-01-08': {'COVID-19_healthcare_admissionByDay': 776.0,
#   'COVID-19_cases_casesByDay': 2501.0,
#   'COVID-19_deaths_ONSByDay': 103.0},
#  '2023-01-09': {'COVID-19_healthcare_admissionByDay': 737.0,
#   'COVID-19_cases_casesByDay': 3213.0,
#   'COVID-19_deaths_ONSByDay': 109.0},
#  '2023-01-10': {'COVID-19_healthcare_admissionByDay': 661.0,
#   'COVID-19_cases_casesByDay': 2803.0,
#   'COVID-19_deaths_ONSByDay': 87.0},
#  '2023-01-11': {'COVID-19_healthcare_admissionByDay': 692.0,
#   'COVID-19_cases_casesByDay': 2373.0,
#   'COVID-19_deaths_ONSByDay': 77.0},
#  '2023-01-12': {'COVID-19_healthcare_admissionByDay': 664.0,
#   'COVID-19_cases_casesByDay': 2205.0,
#   'COVID-19_deaths_ONSByDay': 103.0},
#  '2023-01-13': {'COVID-19_healthcare_admissionByDay': 510.0,
#   'COVID-19_cases_casesByDay': 1905.0,
#   'COVID-19_deaths_ONSByDay': 83.0},
#  '2023-01-14': {'COVID-19_healthcare_admissionByDay': 417.0,
#   'COVID-19_cases_casesByDay': 1329.0,
#   'COVID-19_deaths_ONSByDay': 86.0},
#  '2023-01-15': {'COVID-19_healthcare_admissionByDay': 567.0,
#   'COVID-19_cases_casesByDay': 1673.0,
#   'COVID-19_deaths_ONSByDay': 87.0},
#  '2023-01-16': {'COVID-19_healthcare_admissionByDay': 599.0,
#   'COVID-19_cases_casesByDay': 2309.0,
#   'COVID-19_deaths_ONSByDay': 93.0},
#  '2023-01-17': {'COVID-19_healthcare_admissionByDay': 565.0,
#   'COVID-19_cases_casesByDay': 1989.0,
#   'COVID-19_deaths_ONSByDay': 73.0},
#  '2023-01-18': {'COVID-19_healthcare_admissionByDay': 595.0,
#   'COVID-19_cases_casesByDay': 1901.0,
#   'COVID-19_deaths_ONSByDay': 74.0},
#  '2023-01-19': {'COVID-19_healthcare_admissionByDay': 618.0,
#   'COVID-19_cases_casesByDay': 1809.0,
#   'COVID-19_deaths_ONSByDay': 71.0},
#  '2023-01-20': {'COVID-19_healthcare_admissionByDay': 447.0,
#   'COVID-19_cases_casesByDay': 1699.0,
#   'COVID-19_deaths_ONSByDay': 66.0},
#  '2023-01-21': {'COVID-19_healthcare_admissionByDay': 493.0,
#   'COVID-19_cases_casesByDay': 1400.0,
#   'COVID-19_deaths_ONSByDay': 65.0},
#  '2023-01-22': {'COVID-19_healthcare_admissionByDay': 590.0,
#   'COVID-19_cases_casesByDay': 1748.0,
#   'COVID-19_deaths_ONSByDay': 69.0},
#  '2023-01-23': {'COVID-19_healthcare_admissionByDay': 617.0,
#   'COVID-19_cases_casesByDay': 2384.0,
#   'COVID-19_deaths_ONSByDay': 59.0},
#  '2023-01-24': {'COVID-19_healthcare_admissionByDay': 695.0,
#   'COVID-19_cases_casesByDay': 2552.0,
#   'COVID-19_deaths_ONSByDay': 71.0},
#  '2023-01-25': {'COVID-19_healthcare_admissionByDay': 706.0,
#   'COVID-19_cases_casesByDay': 2423.0,
#   'COVID-19_deaths_ONSByDay': 54.0},
#  '2023-01-26': {'COVID-19_healthcare_admissionByDay': 654.0,
#   'COVID-19_cases_casesByDay': 2337.0,
#   'COVID-19_deaths_ONSByDay': 63.0},
#  '2023-01-27': {'COVID-19_healthcare_admissionByDay': 558.0,
#   'COVID-19_cases_casesByDay': 2270.0,
#   'COVID-19_deaths_ONSByDay': 68.0},
#  '2023-01-28': {'COVID-19_healthcare_admissionByDay': 562.0,
#   'COVID-19_cases_casesByDay': 1803.0,
#   'COVID-19_deaths_ONSByDay': 62.0},
#  '2023-01-29': {'COVID-19_healthcare_admissionByDay': 705.0,
#   'COVID-19_cases_casesByDay': 2250.0,
#   'COVID-19_deaths_ONSByDay': 65.0},
#  '2023-01-30': {'COVID-19_healthcare_admissionByDay': 741.0,
#   'COVID-19_cases_casesByDay': 3270.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2023-01-31': {'COVID-19_healthcare_admissionByDay': 752.0,
#   'COVID-19_cases_casesByDay': 3281.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2023-02-01': {'COVID-19_healthcare_admissionByDay': 780.0,
#   'COVID-19_cases_casesByDay': 3214.0,
#   'COVID-19_deaths_ONSByDay': 61.0},
#  '2023-02-02': {'COVID-19_healthcare_admissionByDay': 713.0,
#   'COVID-19_cases_casesByDay': 2956.0,
#   'COVID-19_deaths_ONSByDay': 69.0},
#  '2023-02-03': {'COVID-19_healthcare_admissionByDay': 573.0,
#   'COVID-19_cases_casesByDay': 2752.0,
#   'COVID-19_deaths_ONSByDay': 58.0},
#  '2023-02-04': {'COVID-19_healthcare_admissionByDay': 668.0,
#   'COVID-19_cases_casesByDay': 2225.0,
#   'COVID-19_deaths_ONSByDay': 52.0},
#  '2023-02-05': {'COVID-19_healthcare_admissionByDay': 747.0,
#   'COVID-19_cases_casesByDay': 2616.0,
#   'COVID-19_deaths_ONSByDay': 65.0},
#  '2023-02-06': {'COVID-19_healthcare_admissionByDay': 825.0,
#   'COVID-19_cases_casesByDay': 3621.0,
#   'COVID-19_deaths_ONSByDay': 49.0},
#  '2023-02-07': {'COVID-19_healthcare_admissionByDay': 817.0,
#   'COVID-19_cases_casesByDay': 3396.0,
#   'COVID-19_deaths_ONSByDay': 60.0},
#  '2023-02-08': {'COVID-19_healthcare_admissionByDay': 768.0,
#   'COVID-19_cases_casesByDay': 3335.0,
#   'COVID-19_deaths_ONSByDay': 63.0},
#  '2023-02-09': {'COVID-19_healthcare_admissionByDay': 818.0,
#   'COVID-19_cases_casesByDay': 3045.0,
#   'COVID-19_deaths_ONSByDay': 49.0},
#  '2023-02-10': {'COVID-19_healthcare_admissionByDay': 643.0,
#   'COVID-19_cases_casesByDay': 3051.0,
#   'COVID-19_deaths_ONSByDay': 69.0},
#  '2023-02-11': {'COVID-19_healthcare_admissionByDay': 743.0,
#   'COVID-19_cases_casesByDay': 2398.0,
#   'COVID-19_deaths_ONSByDay': 57.0},
#  '2023-02-12': {'COVID-19_healthcare_admissionByDay': 866.0,
#   'COVID-19_cases_casesByDay': 2920.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2023-02-13': {'COVID-19_healthcare_admissionByDay': 949.0,
#   'COVID-19_cases_casesByDay': 4551.0,
#   'COVID-19_deaths_ONSByDay': 46.0},
#  '2023-02-14': {'COVID-19_healthcare_admissionByDay': 912.0,
#   'COVID-19_cases_casesByDay': 4357.0,
#   'COVID-19_deaths_ONSByDay': 71.0},
#  '2023-02-15': {'COVID-19_healthcare_admissionByDay': 978.0,
#   'COVID-19_cases_casesByDay': 3894.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2023-02-16': {'COVID-19_healthcare_admissionByDay': 959.0,
#   'COVID-19_cases_casesByDay': 4005.0,
#   'COVID-19_deaths_ONSByDay': 68.0},
#  '2023-02-17': {'COVID-19_healthcare_admissionByDay': 785.0,
#   'COVID-19_cases_casesByDay': 3780.0,
#   'COVID-19_deaths_ONSByDay': 71.0},
#  '2023-02-18': {'COVID-19_healthcare_admissionByDay': 749.0,
#   'COVID-19_cases_casesByDay': 2907.0,
#   'COVID-19_deaths_ONSByDay': 65.0},
#  '2023-02-19': {'COVID-19_healthcare_admissionByDay': 912.0,
#   'COVID-19_cases_casesByDay': 3436.0,
#   'COVID-19_deaths_ONSByDay': 52.0},
#  '2023-02-20': {'COVID-19_healthcare_admissionByDay': 983.0,
#   'COVID-19_cases_casesByDay': 4554.0,
#   'COVID-19_deaths_ONSByDay': 68.0},
#  '2023-02-21': {'COVID-19_healthcare_admissionByDay': 967.0,
#   'COVID-19_cases_casesByDay': 4326.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2023-02-22': {'COVID-19_healthcare_admissionByDay': 879.0,
#   'COVID-19_cases_casesByDay': 3856.0,
#   'COVID-19_deaths_ONSByDay': 78.0},
#  '2023-02-23': {'COVID-19_healthcare_admissionByDay': 845.0,
#   'COVID-19_cases_casesByDay': 3474.0,
#   'COVID-19_deaths_ONSByDay': 68.0},
#  '2023-02-24': {'COVID-19_healthcare_admissionByDay': 665.0,
#   'COVID-19_cases_casesByDay': 3112.0,
#   'COVID-19_deaths_ONSByDay': 72.0},
#  '2023-02-25': {'COVID-19_healthcare_admissionByDay': 729.0,
#   'COVID-19_cases_casesByDay': 2529.0,
#   'COVID-19_deaths_ONSByDay': 66.0},
#  '2023-02-26': {'COVID-19_healthcare_admissionByDay': 893.0,
#   'COVID-19_cases_casesByDay': 2901.0,
#   'COVID-19_deaths_ONSByDay': 77.0},
#  '2023-02-27': {'COVID-19_healthcare_admissionByDay': 933.0,
#   'COVID-19_cases_casesByDay': 4319.0,
#   'COVID-19_deaths_ONSByDay': 70.0},
#  '2023-02-28': {'COVID-19_healthcare_admissionByDay': 942.0,
#   'COVID-19_cases_casesByDay': 4152.0,
#   'COVID-19_deaths_ONSByDay': 71.0},
#  '2023-03-01': {'COVID-19_healthcare_admissionByDay': 993.0,
#   'COVID-19_cases_casesByDay': 3973.0,
#   'COVID-19_deaths_ONSByDay': 63.0},
#  '2023-03-02': {'COVID-19_healthcare_admissionByDay': 947.0,
#   'COVID-19_cases_casesByDay': 3567.0,
#   'COVID-19_deaths_ONSByDay': 90.0},
#  '2023-03-03': {'COVID-19_healthcare_admissionByDay': 750.0,
#   'COVID-19_cases_casesByDay': 3420.0,
#   'COVID-19_deaths_ONSByDay': 65.0},
#  '2023-03-04': {'COVID-19_healthcare_admissionByDay': 743.0,
#   'COVID-19_cases_casesByDay': 2573.0,
#   'COVID-19_deaths_ONSByDay': 84.0},
#  '2023-03-05': {'COVID-19_healthcare_admissionByDay': 874.0,
#   'COVID-19_cases_casesByDay': 3155.0,
#   'COVID-19_deaths_ONSByDay': 83.0},
#  '2023-03-06': {'COVID-19_healthcare_admissionByDay': 1039.0,
#   'COVID-19_cases_casesByDay': 4580.0,
#   'COVID-19_deaths_ONSByDay': 80.0},
#  '2023-03-07': {'COVID-19_healthcare_admissionByDay': 1045.0,
#   'COVID-19_cases_casesByDay': 4457.0,
#   'COVID-19_deaths_ONSByDay': 79.0},
#  '2023-03-08': {'COVID-19_healthcare_admissionByDay': 1122.0,
#   'COVID-19_cases_casesByDay': 4318.0,
#   'COVID-19_deaths_ONSByDay': 80.0},
#  '2023-03-09': {'COVID-19_healthcare_admissionByDay': 978.0,
#   'COVID-19_cases_casesByDay': 3963.0,
#   'COVID-19_deaths_ONSByDay': 78.0},
#  '2023-03-10': {'COVID-19_healthcare_admissionByDay': 783.0,
#   'COVID-19_cases_casesByDay': 3592.0,
#   'COVID-19_deaths_ONSByDay': 77.0},
#  '2023-03-11': {'COVID-19_healthcare_admissionByDay': 870.0,
#   'COVID-19_cases_casesByDay': 3084.0,
#   'COVID-19_deaths_ONSByDay': 81.0},
#  '2023-03-12': {'COVID-19_healthcare_admissionByDay': 1071.0,
#   'COVID-19_cases_casesByDay': 4029.0,
#   'COVID-19_deaths_ONSByDay': 84.0},
#  '2023-03-13': {'COVID-19_healthcare_admissionByDay': 1189.0,
#   'COVID-19_cases_casesByDay': 5285.0,
#   'COVID-19_deaths_ONSByDay': 86.0},
#  '2023-03-14': {'COVID-19_healthcare_admissionByDay': 1100.0,
#   'COVID-19_cases_casesByDay': 5073.0,
#   'COVID-19_deaths_ONSByDay': 82.0},
#  '2023-03-15': {'COVID-19_healthcare_admissionByDay': 1011.0,
#   'COVID-19_cases_casesByDay': 4372.0,
#   'COVID-19_deaths_ONSByDay': 91.0},
#  '2023-03-16': {'COVID-19_healthcare_admissionByDay': 1076.0,
#   'COVID-19_cases_casesByDay': 4350.0,
#   'COVID-19_deaths_ONSByDay': 85.0},
#  '2023-03-17': {'COVID-19_healthcare_admissionByDay': 842.0,
#   'COVID-19_cases_casesByDay': 3718.0,
#   'COVID-19_deaths_ONSByDay': 95.0},
#  '2023-03-18': {'COVID-19_healthcare_admissionByDay': 853.0,
#   'COVID-19_cases_casesByDay': 3109.0,
#   'COVID-19_deaths_ONSByDay': 83.0},
#  '2023-03-19': {'COVID-19_healthcare_admissionByDay': 1049.0,
#   'COVID-19_cases_casesByDay': 3683.0,
#   'COVID-19_deaths_ONSByDay': 78.0},
#  '2023-03-20': {'COVID-19_healthcare_admissionByDay': 1019.0,
#   'COVID-19_cases_casesByDay': 4729.0,
#   'COVID-19_deaths_ONSByDay': 74.0},
#  '2023-03-21': {'COVID-19_healthcare_admissionByDay': 1065.0,
#   'COVID-19_cases_casesByDay': 4747.0,
#   'COVID-19_deaths_ONSByDay': 102.0},
#  '2023-03-22': {'COVID-19_healthcare_admissionByDay': 1028.0,
#   'COVID-19_cases_casesByDay': 4326.0,
#   'COVID-19_deaths_ONSByDay': 86.0},
#  '2023-03-23': {'COVID-19_healthcare_admissionByDay': 1011.0,
#   'COVID-19_cases_casesByDay': 3969.0,
#   'COVID-19_deaths_ONSByDay': 91.0},
#  '2023-03-24': {'COVID-19_healthcare_admissionByDay': 762.0,
#   'COVID-19_cases_casesByDay': 3745.0,
#   'COVID-19_deaths_ONSByDay': 94.0},
#  '2023-03-25': {'COVID-19_healthcare_admissionByDay': 730.0,
#   'COVID-19_cases_casesByDay': 2747.0,
#   'COVID-19_deaths_ONSByDay': 94.0},
#  '2023-03-26': {'COVID-19_healthcare_admissionByDay': 825.0,
#   'COVID-19_cases_casesByDay': 3156.0,
#   'COVID-19_deaths_ONSByDay': 70.0},
#  '2023-03-27': {'COVID-19_healthcare_admissionByDay': 886.0,
#   'COVID-19_cases_casesByDay': 3926.0,
#   'COVID-19_deaths_ONSByDay': 85.0},
#  '2023-03-28': {'COVID-19_healthcare_admissionByDay': 934.0,
#   'COVID-19_cases_casesByDay': 3594.0,
#   'COVID-19_deaths_ONSByDay': 95.0},
#  '2023-03-29': {'COVID-19_healthcare_admissionByDay': 1021.0,
#   'COVID-19_cases_casesByDay': 3438.0,
#   'COVID-19_deaths_ONSByDay': 78.0},
#  '2023-03-30': {'COVID-19_healthcare_admissionByDay': 847.0,
#   'COVID-19_cases_casesByDay': 3051.0,
#   'COVID-19_deaths_ONSByDay': 88.0},
#  '2023-03-31': {'COVID-19_healthcare_admissionByDay': 699.0,
#   'COVID-19_cases_casesByDay': 2510.0,
#   'COVID-19_deaths_ONSByDay': 62.0},
#  '2023-04-01': {'COVID-19_healthcare_admissionByDay': 718.0,
#   'COVID-19_cases_casesByDay': 2083.0,
#   'COVID-19_deaths_ONSByDay': 60.0},
#  '2023-04-02': {'COVID-19_healthcare_admissionByDay': 771.0,
#   'COVID-19_cases_casesByDay': 2249.0,
#   'COVID-19_deaths_ONSByDay': 61.0},
#  '2023-04-03': {'COVID-19_healthcare_admissionByDay': 770.0,
#   'COVID-19_cases_casesByDay': 2459.0,
#   'COVID-19_deaths_ONSByDay': 79.0},
#  '2023-04-04': {'COVID-19_healthcare_admissionByDay': 786.0,
#   'COVID-19_cases_casesByDay': 2185.0,
#   'COVID-19_deaths_ONSByDay': 83.0},
#  '2023-04-05': {'COVID-19_healthcare_admissionByDay': 774.0,
#   'COVID-19_cases_casesByDay': 2237.0,
#   'COVID-19_deaths_ONSByDay': 51.0},
#  '2023-04-06': {'COVID-19_healthcare_admissionByDay': 619.0,
#   'COVID-19_cases_casesByDay': 1967.0,
#   'COVID-19_deaths_ONSByDay': 89.0},
#  '2023-04-07': {'COVID-19_healthcare_admissionByDay': 520.0,
#   'COVID-19_cases_casesByDay': 1599.0,
#   'COVID-19_deaths_ONSByDay': 76.0},
#  '2023-04-08': {'COVID-19_healthcare_admissionByDay': 526.0,
#   'COVID-19_cases_casesByDay': 1531.0,
#   'COVID-19_deaths_ONSByDay': 59.0},
#  '2023-04-09': {'COVID-19_healthcare_admissionByDay': 612.0,
#   'COVID-19_cases_casesByDay': 1643.0,
#   'COVID-19_deaths_ONSByDay': 56.0},
#  '2023-04-10': {'COVID-19_healthcare_admissionByDay': 719.0,
#   'COVID-19_cases_casesByDay': 2135.0,
#   'COVID-19_deaths_ONSByDay': 67.0},
#  '2023-04-11': {'COVID-19_healthcare_admissionByDay': 723.0,
#   'COVID-19_cases_casesByDay': 2282.0,
#   'COVID-19_deaths_ONSByDay': 57.0},
#  '2023-04-12': {'COVID-19_healthcare_admissionByDay': 628.0,
#   'COVID-19_cases_casesByDay': 2056.0,
#   'COVID-19_deaths_ONSByDay': 63.0},
#  '2023-04-13': {'COVID-19_healthcare_admissionByDay': 620.0,
#   'COVID-19_cases_casesByDay': 1880.0,
#   'COVID-19_deaths_ONSByDay': 75.0},
#  '2023-04-14': {'COVID-19_healthcare_admissionByDay': 492.0,
#   'COVID-19_cases_casesByDay': 1553.0,
#   'COVID-19_deaths_ONSByDay': 63.0},
#  '2023-04-15': {'COVID-19_healthcare_admissionByDay': 509.0,
#   'COVID-19_cases_casesByDay': 1272.0,
#   'COVID-19_deaths_ONSByDay': 60.0},
#  '2023-04-16': {'COVID-19_healthcare_admissionByDay': 576.0,
#   'COVID-19_cases_casesByDay': 1788.0,
#   'COVID-19_deaths_ONSByDay': 58.0},
#  '2023-04-17': {'COVID-19_healthcare_admissionByDay': 659.0,
#   'COVID-19_cases_casesByDay': 2060.0,
#   'COVID-19_deaths_ONSByDay': 52.0},
#  '2023-04-18': {'COVID-19_healthcare_admissionByDay': 557.0,
#   'COVID-19_cases_casesByDay': 1803.0,
#   'COVID-19_deaths_ONSByDay': 54.0},
#  '2023-04-19': {'COVID-19_healthcare_admissionByDay': 566.0,
#   'COVID-19_cases_casesByDay': 1703.0,
#   'COVID-19_deaths_ONSByDay': 64.0},
#  '2023-04-20': {'COVID-19_healthcare_admissionByDay': 493.0,
#   'COVID-19_cases_casesByDay': 1488.0,
#   'COVID-19_deaths_ONSByDay': 54.0},
#  '2023-04-21': {'COVID-19_healthcare_admissionByDay': 428.0,
#   'COVID-19_cases_casesByDay': 1343.0,
#   'COVID-19_deaths_ONSByDay': 74.0},
#  '2023-04-22': {'COVID-19_healthcare_admissionByDay': 411.0,
#   'COVID-19_cases_casesByDay': 1191.0,
#   'COVID-19_deaths_ONSByDay': 45.0},
#  '2023-04-23': {'COVID-19_healthcare_admissionByDay': 570.0,
#   'COVID-19_cases_casesByDay': 1433.0,
#   'COVID-19_deaths_ONSByDay': 54.0},
#  '2023-04-24': {'COVID-19_healthcare_admissionByDay': 525.0,
#   'COVID-19_cases_casesByDay': 1708.0,
#   'COVID-19_deaths_ONSByDay': 41.0},
#  '2023-04-25': {'COVID-19_healthcare_admissionByDay': 511.0,
#   'COVID-19_cases_casesByDay': 1605.0,
#   'COVID-19_deaths_ONSByDay': 45.0},
#  '2023-04-26': {'COVID-19_healthcare_admissionByDay': 539.0,
#   'COVID-19_cases_casesByDay': 1569.0,
#   'COVID-19_deaths_ONSByDay': 51.0},
#  '2023-04-27': {'COVID-19_healthcare_admissionByDay': 525.0,
#   'COVID-19_cases_casesByDay': 1514.0,
#   'COVID-19_deaths_ONSByDay': 42.0},
#  ...}

# %% [markdown]
# Note that some of the metrics are missing for some dates, and the keys ate not sorted by date, but by insertion:

# %%
data['2020-01-30']
# Out:
# {'COVID-19_cases_casesByDay': 1.0, 'COVID-19_deaths_ONSByDay': 1.0}

# %% [markdown]
# We then want to extract all the dates and sort them. Luckily, with dates written year-first, alphabetical ordering does the trick.

# %%
dates=list(data.keys())
dates.sort()
dates
# Out:
# ['2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
#  '2020-03-20',
#  '2020-03-21',
#  '2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28',
#  '2020-05-29',
#  '2020-05-30',
#  '2020-05-31',
#  '2020-06-01',
#  '2020-06-02',
#  '2020-06-03',
#  '2020-06-04',
#  '2020-06-05',
#  '2020-06-06',
#  '2020-06-07',
#  '2020-06-08',
#  '2020-06-09',
#  '2020-06-10',
#  '2020-06-11',
#  '2020-06-12',
#  '2020-06-13',
#  '2020-06-14',
#  '2020-06-15',
#  '2020-06-16',
#  '2020-06-17',
#  '2020-06-18',
#  '2020-06-19',
#  '2020-06-20',
#  '2020-06-21',
#  '2020-06-22',
#  '2020-06-23',
#  '2020-06-24',
#  '2020-06-25',
#  '2020-06-26',
#  '2020-06-27',
#  '2020-06-28',
#  '2020-06-29',
#  '2020-06-30',
#  '2020-07-01',
#  '2020-07-02',
#  '2020-07-03',
#  '2020-07-04',
#  '2020-07-05',
#  '2020-07-06',
#  '2020-07-07',
#  '2020-07-08',
#  '2020-07-09',
#  '2020-07-10',
#  '2020-07-11',
#  '2020-07-12',
#  '2020-07-13',
#  '2020-07-14',
#  '2020-07-15',
#  '2020-07-16',
#  '2020-07-17',
#  '2020-07-18',
#  '2020-07-19',
#  '2020-07-20',
#  '2020-07-21',
#  '2020-07-22',
#  '2020-07-23',
#  '2020-07-24',
#  '2020-07-25',
#  '2020-07-26',
#  '2020-07-27',
#  '2020-07-28',
#  '2020-07-29',
#  '2020-07-30',
#  '2020-07-31',
#  '2020-08-01',
#  '2020-08-02',
#  '2020-08-03',
#  '2020-08-04',
#  '2020-08-05',
#  '2020-08-06',
#  '2020-08-07',
#  '2020-08-08',
#  '2020-08-09',
#  '2020-08-10',
#  '2020-08-11',
#  '2020-08-12',
#  '2020-08-13',
#  '2020-08-14',
#  '2020-08-15',
#  '2020-08-16',
#  '2020-08-17',
#  '2020-08-18',
#  '2020-08-19',
#  '2020-08-20',
#  '2020-08-21',
#  '2020-08-22',
#  '2020-08-23',
#  '2020-08-24',
#  '2020-08-25',
#  '2020-08-26',
#  '2020-08-27',
#  '2020-08-28',
#  '2020-08-29',
#  '2020-08-30',
#  '2020-08-31',
#  '2020-09-01',
#  '2020-09-02',
#  '2020-09-03',
#  '2020-09-04',
#  '2020-09-05',
#  '2020-09-06',
#  '2020-09-07',
#  '2020-09-08',
#  '2020-09-09',
#  '2020-09-10',
#  '2020-09-11',
#  '2020-09-12',
#  '2020-09-13',
#  '2020-09-14',
#  '2020-09-15',
#  '2020-09-16',
#  '2020-09-17',
#  '2020-09-18',
#  '2020-09-19',
#  '2020-09-20',
#  '2020-09-21',
#  '2020-09-22',
#  '2020-09-23',
#  '2020-09-24',
#  '2020-09-25',
#  '2020-09-26',
#  '2020-09-27',
#  '2020-09-28',
#  '2020-09-29',
#  '2020-09-30',
#  '2020-10-01',
#  '2020-10-02',
#  '2020-10-03',
#  '2020-10-04',
#  '2020-10-05',
#  '2020-10-06',
#  '2020-10-07',
#  '2020-10-08',
#  '2020-10-09',
#  '2020-10-10',
#  '2020-10-11',
#  '2020-10-12',
#  '2020-10-13',
#  '2020-10-14',
#  '2020-10-15',
#  '2020-10-16',
#  '2020-10-17',
#  '2020-10-18',
#  '2020-10-19',
#  '2020-10-20',
#  '2020-10-21',
#  '2020-10-22',
#  '2020-10-23',
#  '2020-10-24',
#  '2020-10-25',
#  '2020-10-26',
#  '2020-10-27',
#  '2020-10-28',
#  '2020-10-29',
#  '2020-10-30',
#  '2020-10-31',
#  '2020-11-01',
#  '2020-11-02',
#  '2020-11-03',
#  '2020-11-04',
#  '2020-11-05',
#  '2020-11-06',
#  '2020-11-07',
#  '2020-11-08',
#  '2020-11-09',
#  '2020-11-10',
#  '2020-11-11',
#  '2020-11-12',
#  '2020-11-13',
#  '2020-11-14',
#  '2020-11-15',
#  '2020-11-16',
#  '2020-11-17',
#  '2020-11-18',
#  '2020-11-19',
#  '2020-11-20',
#  '2020-11-21',
#  '2020-11-22',
#  '2020-11-23',
#  '2020-11-24',
#  '2020-11-25',
#  '2020-11-26',
#  '2020-11-27',
#  '2020-11-28',
#  '2020-11-29',
#  '2020-11-30',
#  '2020-12-01',
#  '2020-12-02',
#  '2020-12-03',
#  '2020-12-04',
#  '2020-12-05',
#  '2020-12-06',
#  '2020-12-07',
#  '2020-12-08',
#  '2020-12-09',
#  '2020-12-10',
#  '2020-12-11',
#  '2020-12-12',
#  '2020-12-13',
#  '2020-12-14',
#  '2020-12-15',
#  '2020-12-16',
#  '2020-12-17',
#  '2020-12-18',
#  '2020-12-19',
#  '2020-12-20',
#  '2020-12-21',
#  '2020-12-22',
#  '2020-12-23',
#  '2020-12-24',
#  '2020-12-25',
#  '2020-12-26',
#  '2020-12-27',
#  '2020-12-28',
#  '2020-12-29',
#  '2020-12-30',
#  '2020-12-31',
#  '2021-01-01',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-04',
#  '2021-02-05',
#  '2021-02-06',
#  '2021-02-07',
#  '2021-02-08',
#  '2021-02-09',
#  '2021-02-10',
#  '2021-02-11',
#  '2021-02-12',
#  '2021-02-13',
#  '2021-02-14',
#  '2021-02-15',
#  '2021-02-16',
#  '2021-02-17',
#  '2021-02-18',
#  '2021-02-19',
#  '2021-02-20',
#  '2021-02-21',
#  '2021-02-22',
#  '2021-02-23',
#  '2021-02-24',
#  '2021-02-25',
#  '2021-02-26',
#  '2021-02-27',
#  '2021-02-28',
#  '2021-03-01',
#  '2021-03-02',
#  '2021-03-03',
#  '2021-03-04',
#  '2021-03-05',
#  '2021-03-06',
#  '2021-03-07',
#  '2021-03-08',
#  '2021-03-09',
#  '2021-03-10',
#  '2021-03-11',
#  '2021-03-12',
#  '2021-03-13',
#  '2021-03-14',
#  '2021-03-15',
#  '2021-03-16',
#  '2021-03-17',
#  '2021-03-18',
#  '2021-03-19',
#  '2021-03-20',
#  '2021-03-21',
#  '2021-03-22',
#  '2021-03-23',
#  '2021-03-24',
#  '2021-03-25',
#  '2021-03-26',
#  '2021-03-27',
#  '2021-03-28',
#  '2021-03-29',
#  '2021-03-30',
#  '2021-03-31',
#  '2021-04-01',
#  '2021-04-02',
#  '2021-04-03',
#  '2021-04-04',
#  '2021-04-05',
#  '2021-04-06',
#  '2021-04-07',
#  '2021-04-08',
#  '2021-04-09',
#  '2021-04-10',
#  '2021-04-11',
#  '2021-04-12',
#  '2021-04-13',
#  '2021-04-14',
#  '2021-04-15',
#  '2021-04-16',
#  '2021-04-17',
#  '2021-04-18',
#  '2021-04-19',
#  '2021-04-20',
#  '2021-04-21',
#  '2021-04-22',
#  '2021-04-23',
#  '2021-04-24',
#  '2021-04-25',
#  '2021-04-26',
#  '2021-04-27',
#  '2021-04-28',
#  '2021-04-29',
#  '2021-04-30',
#  '2021-05-01',
#  '2021-05-02',
#  '2021-05-03',
#  '2021-05-04',
#  '2021-05-05',
#  '2021-05-06',
#  '2021-05-07',
#  '2021-05-08',
#  '2021-05-09',
#  '2021-05-10',
#  '2021-05-11',
#  '2021-05-12',
#  '2021-05-13',
#  '2021-05-14',
#  '2021-05-15',
#  '2021-05-16',
#  '2021-05-17',
#  '2021-05-18',
#  '2021-05-19',
#  '2021-05-20',
#  '2021-05-21',
#  '2021-05-22',
#  '2021-05-23',
#  '2021-05-24',
#  '2021-05-25',
#  '2021-05-26',
#  '2021-05-27',
#  '2021-05-28',
#  '2021-05-29',
#  '2021-05-30',
#  '2021-05-31',
#  '2021-06-01',
#  '2021-06-02',
#  '2021-06-03',
#  '2021-06-04',
#  '2021-06-05',
#  '2021-06-06',
#  '2021-06-07',
#  '2021-06-08',
#  '2021-06-09',
#  '2021-06-10',
#  '2021-06-11',
#  '2021-06-12',
#  '2021-06-13',
#  '2021-06-14',
#  '2021-06-15',
#  '2021-06-16',
#  '2021-06-17',
#  '2021-06-18',
#  '2021-06-19',
#  '2021-06-20',
#  '2021-06-21',
#  '2021-06-22',
#  '2021-06-23',
#  '2021-06-24',
#  '2021-06-25',
#  '2021-06-26',
#  '2021-06-27',
#  '2021-06-28',
#  '2021-06-29',
#  '2021-06-30',
#  '2021-07-01',
#  '2021-07-02',
#  '2021-07-03',
#  '2021-07-04',
#  '2021-07-05',
#  '2021-07-06',
#  '2021-07-07',
#  '2021-07-08',
#  '2021-07-09',
#  '2021-07-10',
#  '2021-07-11',
#  '2021-07-12',
#  '2021-07-13',
#  '2021-07-14',
#  '2021-07-15',
#  '2021-07-16',
#  '2021-07-17',
#  '2021-07-18',
#  '2021-07-19',
#  '2021-07-20',
#  '2021-07-21',
#  '2021-07-22',
#  '2021-07-23',
#  '2021-07-24',
#  '2021-07-25',
#  '2021-07-26',
#  '2021-07-27',
#  '2021-07-28',
#  '2021-07-29',
#  '2021-07-30',
#  '2021-07-31',
#  '2021-08-01',
#  '2021-08-02',
#  '2021-08-03',
#  '2021-08-04',
#  '2021-08-05',
#  '2021-08-06',
#  '2021-08-07',
#  '2021-08-08',
#  '2021-08-09',
#  '2021-08-10',
#  '2021-08-11',
#  '2021-08-12',
#  '2021-08-13',
#  '2021-08-14',
#  '2021-08-15',
#  '2021-08-16',
#  '2021-08-17',
#  '2021-08-18',
#  '2021-08-19',
#  '2021-08-20',
#  '2021-08-21',
#  '2021-08-22',
#  '2021-08-23',
#  '2021-08-24',
#  '2021-08-25',
#  '2021-08-26',
#  '2021-08-27',
#  '2021-08-28',
#  '2021-08-29',
#  '2021-08-30',
#  '2021-08-31',
#  '2021-09-01',
#  '2021-09-02',
#  '2021-09-03',
#  '2021-09-04',
#  '2021-09-05',
#  '2021-09-06',
#  '2021-09-07',
#  '2021-09-08',
#  '2021-09-09',
#  '2021-09-10',
#  '2021-09-11',
#  '2021-09-12',
#  '2021-09-13',
#  '2021-09-14',
#  '2021-09-15',
#  '2021-09-16',
#  '2021-09-17',
#  '2021-09-18',
#  '2021-09-19',
#  '2021-09-20',
#  '2021-09-21',
#  '2021-09-22',
#  '2021-09-23',
#  '2021-09-24',
#  '2021-09-25',
#  '2021-09-26',
#  '2021-09-27',
#  '2021-09-28',
#  '2021-09-29',
#  '2021-09-30',
#  '2021-10-01',
#  '2021-10-02',
#  '2021-10-03',
#  '2021-10-04',
#  '2021-10-05',
#  '2021-10-06',
#  '2021-10-07',
#  '2021-10-08',
#  '2021-10-09',
#  '2021-10-10',
#  '2021-10-11',
#  '2021-10-12',
#  '2021-10-13',
#  '2021-10-14',
#  '2021-10-15',
#  '2021-10-16',
#  '2021-10-17',
#  '2021-10-18',
#  '2021-10-19',
#  '2021-10-20',
#  '2021-10-21',
#  '2021-10-22',
#  '2021-10-23',
#  '2021-10-24',
#  '2021-10-25',
#  '2021-10-26',
#  '2021-10-27',
#  '2021-10-28',
#  '2021-10-29',
#  '2021-10-30',
#  '2021-10-31',
#  '2021-11-01',
#  '2021-11-02',
#  '2021-11-03',
#  '2021-11-04',
#  '2021-11-05',
#  '2021-11-06',
#  '2021-11-07',
#  '2021-11-08',
#  '2021-11-09',
#  '2021-11-10',
#  '2021-11-11',
#  '2021-11-12',
#  '2021-11-13',
#  '2021-11-14',
#  '2021-11-15',
#  '2021-11-16',
#  '2021-11-17',
#  '2021-11-18',
#  '2021-11-19',
#  '2021-11-20',
#  '2021-11-21',
#  '2021-11-22',
#  '2021-11-23',
#  '2021-11-24',
#  '2021-11-25',
#  '2021-11-26',
#  '2021-11-27',
#  '2021-11-28',
#  '2021-11-29',
#  '2021-11-30',
#  '2021-12-01',
#  '2021-12-02',
#  '2021-12-03',
#  '2021-12-04',
#  '2021-12-05',
#  '2021-12-06',
#  '2021-12-07',
#  '2021-12-08',
#  '2021-12-09',
#  '2021-12-10',
#  '2021-12-11',
#  '2021-12-12',
#  '2021-12-13',
#  '2021-12-14',
#  '2021-12-15',
#  '2021-12-16',
#  '2021-12-17',
#  '2021-12-18',
#  '2021-12-19',
#  '2021-12-20',
#  '2021-12-21',
#  '2021-12-22',
#  '2021-12-23',
#  '2021-12-24',
#  '2021-12-25',
#  '2021-12-26',
#  '2021-12-27',
#  '2021-12-28',
#  '2021-12-29',
#  '2021-12-30',
#  '2021-12-31',
#  '2022-01-01',
#  '2022-01-02',
#  '2022-01-03',
#  '2022-01-04',
#  '2022-01-05',
#  '2022-01-06',
#  '2022-01-07',
#  '2022-01-08',
#  '2022-01-09',
#  '2022-01-10',
#  '2022-01-11',
#  '2022-01-12',
#  '2022-01-13',
#  '2022-01-14',
#  '2022-01-15',
#  '2022-01-16',
#  '2022-01-17',
#  '2022-01-18',
#  '2022-01-19',
#  '2022-01-20',
#  '2022-01-21',
#  '2022-01-22',
#  '2022-01-23',
#  '2022-01-24',
#  '2022-01-25',
#  '2022-01-26',
#  '2022-01-27',
#  '2022-01-28',
#  '2022-01-29',
#  '2022-01-30',
#  '2022-01-31',
#  '2022-02-01',
#  '2022-02-02',
#  '2022-02-03',
#  '2022-02-04',
#  '2022-02-05',
#  '2022-02-06',
#  '2022-02-07',
#  '2022-02-08',
#  '2022-02-09',
#  '2022-02-10',
#  '2022-02-11',
#  '2022-02-12',
#  '2022-02-13',
#  '2022-02-14',
#  '2022-02-15',
#  '2022-02-16',
#  '2022-02-17',
#  '2022-02-18',
#  '2022-02-19',
#  '2022-02-20',
#  '2022-02-21',
#  '2022-02-22',
#  '2022-02-23',
#  '2022-02-24',
#  '2022-02-25',
#  '2022-02-26',
#  '2022-02-27',
#  '2022-02-28',
#  '2022-03-01',
#  '2022-03-02',
#  '2022-03-03',
#  '2022-03-04',
#  '2022-03-05',
#  '2022-03-06',
#  '2022-03-07',
#  '2022-03-08',
#  '2022-03-09',
#  '2022-03-10',
#  '2022-03-11',
#  '2022-03-12',
#  '2022-03-13',
#  '2022-03-14',
#  '2022-03-15',
#  '2022-03-16',
#  '2022-03-17',
#  '2022-03-18',
#  '2022-03-19',
#  '2022-03-20',
#  '2022-03-21',
#  '2022-03-22',
#  '2022-03-23',
#  '2022-03-24',
#  '2022-03-25',
#  '2022-03-26',
#  '2022-03-27',
#  '2022-03-28',
#  '2022-03-29',
#  '2022-03-30',
#  '2022-03-31',
#  '2022-04-01',
#  '2022-04-02',
#  '2022-04-03',
#  '2022-04-04',
#  '2022-04-05',
#  '2022-04-06',
#  '2022-04-07',
#  '2022-04-08',
#  '2022-04-09',
#  '2022-04-10',
#  '2022-04-11',
#  '2022-04-12',
#  '2022-04-13',
#  '2022-04-14',
#  '2022-04-15',
#  '2022-04-16',
#  '2022-04-17',
#  '2022-04-18',
#  '2022-04-19',
#  '2022-04-20',
#  '2022-04-21',
#  '2022-04-22',
#  '2022-04-23',
#  '2022-04-24',
#  '2022-04-25',
#  '2022-04-26',
#  '2022-04-27',
#  '2022-04-28',
#  '2022-04-29',
#  '2022-04-30',
#  '2022-05-01',
#  '2022-05-02',
#  '2022-05-03',
#  '2022-05-04',
#  '2022-05-05',
#  '2022-05-06',
#  '2022-05-07',
#  '2022-05-08',
#  '2022-05-09',
#  '2022-05-10',
#  '2022-05-11',
#  '2022-05-12',
#  '2022-05-13',
#  '2022-05-14',
#  '2022-05-15',
#  '2022-05-16',
#  '2022-05-17',
#  '2022-05-18',
#  '2022-05-19',
#  '2022-05-20',
#  '2022-05-21',
#  '2022-05-22',
#  '2022-05-23',
#  '2022-05-24',
#  '2022-05-25',
#  '2022-05-26',
#  '2022-05-27',
#  '2022-05-28',
#  '2022-05-29',
#  '2022-05-30',
#  '2022-05-31',
#  '2022-06-01',
#  '2022-06-02',
#  '2022-06-03',
#  '2022-06-04',
#  '2022-06-05',
#  '2022-06-06',
#  '2022-06-07',
#  '2022-06-08',
#  '2022-06-09',
#  '2022-06-10',
#  '2022-06-11',
#  '2022-06-12',
#  '2022-06-13',
#  '2022-06-14',
#  '2022-06-15',
#  '2022-06-16',
#  '2022-06-17',
#  '2022-06-18',
#  '2022-06-19',
#  '2022-06-20',
#  '2022-06-21',
#  '2022-06-22',
#  '2022-06-23',
#  '2022-06-24',
#  '2022-06-25',
#  '2022-06-26',
#  '2022-06-27',
#  '2022-06-28',
#  '2022-06-29',
#  '2022-06-30',
#  '2022-07-01',
#  '2022-07-02',
#  '2022-07-03',
#  '2022-07-04',
#  '2022-07-05',
#  '2022-07-06',
#  '2022-07-07',
#  '2022-07-08',
#  '2022-07-09',
#  '2022-07-10',
#  '2022-07-11',
#  '2022-07-12',
#  '2022-07-13',
#  '2022-07-14',
#  '2022-07-15',
#  '2022-07-16',
#  '2022-07-17',
#  '2022-07-18',
#  '2022-07-19',
#  '2022-07-20',
#  '2022-07-21',
#  '2022-07-22',
#  '2022-07-23',
#  '2022-07-24',
#  '2022-07-25',
#  '2022-07-26',
#  '2022-07-27',
#  '2022-07-28',
#  '2022-07-29',
#  '2022-07-30',
#  '2022-07-31',
#  '2022-08-01',
#  '2022-08-02',
#  '2022-08-03',
#  '2022-08-04',
#  '2022-08-05',
#  '2022-08-06',
#  '2022-08-07',
#  '2022-08-08',
#  '2022-08-09',
#  '2022-08-10',
#  '2022-08-11',
#  '2022-08-12',
#  '2022-08-13',
#  '2022-08-14',
#  '2022-08-15',
#  '2022-08-16',
#  '2022-08-17',
#  '2022-08-18',
#  '2022-08-19',
#  '2022-08-20',
#  '2022-08-21',
#  '2022-08-22',
#  '2022-08-23',
#  '2022-08-24',
#  '2022-08-25',
#  '2022-08-26',
#  '2022-08-27',
#  '2022-08-28',
#  '2022-08-29',
#  '2022-08-30',
#  '2022-08-31',
#  '2022-09-01',
#  '2022-09-02',
#  '2022-09-03',
#  '2022-09-04',
#  '2022-09-05',
#  '2022-09-06',
#  '2022-09-07',
#  '2022-09-08',
#  '2022-09-09',
#  '2022-09-10',
#  '2022-09-11',
#  '2022-09-12',
#  '2022-09-13',
#  '2022-09-14',
#  '2022-09-15',
#  '2022-09-16',
#  '2022-09-17',
#  '2022-09-18',
#  '2022-09-19',
#  '2022-09-20',
#  '2022-09-21',
#  '2022-09-22',
#  '2022-09-23',
#  '2022-09-24',
#  '2022-09-25',
#  '2022-09-26',
#  '2022-09-27',
#  '2022-09-28',
#  '2022-09-29',
#  '2022-09-30',
#  '2022-10-01',
#  '2022-10-02',
#  '2022-10-03',
#  '2022-10-04',
#  '2022-10-05',
#  '2022-10-06',
#  '2022-10-07',
#  '2022-10-08',
#  '2022-10-09',
#  '2022-10-10',
#  '2022-10-11',
#  '2022-10-12',
#  '2022-10-13',
#  '2022-10-14',
#  '2022-10-15',
#  '2022-10-16',
#  '2022-10-17',
#  '2022-10-18',
#  '2022-10-19',
#  '2022-10-20',
#  '2022-10-21',
#  '2022-10-22',
#  '2022-10-23',
#  '2022-10-24',
#  '2022-10-25',
#  ...]

# %% [markdown]
# Do not assume this is a proper time series: some dates might be missing. At any rate, we find the earliest and latest date and convert them to the ```pandas``` type for representing dates.

# %%
def parse_date(datestring):
    """ Convert a date string into a pandas datetime object """
    return pd.to_datetime(datestring, format="%Y-%m-%d")

# %%
startdate=parse_date(dates[0])
enddate=parse_date(dates[-1])
print (startdate, ' to ', enddate)
# Out:
# 2020-01-30 00:00:00  to  2025-10-15 00:00:00

# %% [markdown]
# We are now ready to define our ```DataFrame```. To start with, we create an index as a ```date_range```: this is the date analog of a ```range``` for integers, and it will include any dates that may be missing from our list.
# We then proceed to define the ```DateFrame``` by specifying its index and the title of its columns.

# %%
index=pd.date_range(startdate, enddate, freq='D')
timeseriesdf=pd.DataFrame(index=index, columns=['cases', 'admissions', 'deaths'])
timeseriesdf
# Out:
#            cases admissions deaths
# 2020-01-30   NaN        NaN    NaN
# 2020-01-31   NaN        NaN    NaN
# 2020-02-01   NaN        NaN    NaN
# 2020-02-02   NaN        NaN    NaN
# 2020-02-03   NaN        NaN    NaN
# ...          ...        ...    ...
# 2025-10-11   NaN        NaN    NaN
# 2025-10-12   NaN        NaN    NaN
# 2025-10-13   NaN        NaN    NaN
# 2025-10-14   NaN        NaN    NaN
# 2025-10-15   NaN        NaN    NaN
#
# [2086 rows x 3 columns]

# %% [markdown]
# As you can see, the ```DataFrame``` resembles a spreadsheet, or if you want a matrix with labels. We now proceed to fill it in with values from our three statistics. Note that there are many ways of filling in a ```DataFrame```: this is probably not the most efficient, but it is in my view the easiest to understand and one of those that give you more control over the values you enter.

# %%
# translate the columns to our metrics
metrics ={'cases': 'COVID-19_cases_casesByDay',
          'admissions': 'COVID-19_healthcare_admissionByDay',
          'deaths': 'COVID-19_deaths_ONSByDay'}

for date, entry in data.items(): # each entry is a dictionary with cases, admissions and deaths
    pd_date=parse_date(date) # convert to Pandas format
    for column in ['cases', 'admissions', 'deaths']: 
        metric_name=metrics[column]
        # do not assume all values are there for every date - if a value is not available, insert a 0.0
        value= entry.get(metric_name, 0.0)
        # this is the way you access a specific location in the dataframe - use .loc
        # and put index,column in a single set of [ ]
        timeseriesdf.loc[date, column]=value
            
# fill in any remaining "holes" due to missing dates
timeseriesdf.fillna(0.0, inplace=True)
            
timeseriesdf
# Out:
#             cases admissions deaths
# 2020-01-30    1.0        0.0    1.0
# 2020-01-31    0.0        0.0    0.0
# 2020-02-01    0.0        0.0    0.0
# 2020-02-02    1.0        0.0    1.0
# 2020-02-03   18.0        0.0    0.0
# ...           ...        ...    ...
# 2025-10-11  288.0        0.0    0.0
# 2025-10-12  253.0        0.0    0.0
# 2025-10-13  371.0        0.0    0.0
# 2025-10-14  242.0        0.0    0.0
# 2025-10-15   51.0        0.0    0.0
#
# [2086 rows x 3 columns]

# %% [markdown]
# ### Plotting

# %% [markdown]
# Creating a basic plot of our data is now dead easy. We just need to call the ```plot()``` method on our ```DataFrame```; this will call the underlying ```matplot.pyplot``` functions to create a plot of the data. For more options and fancier graphs, see the [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html).

# %%
ax=timeseriesdf.plot() # easy peasy...
ax.set_title('Daily cases, hospital admissions and deaths');

# %% [markdown]
# After lording it for centuries over engineering calculations up to the advent of computers, logarithms had never been so popular as they have become since the rise of Covid dashboards - now everybody and their uncle knows what a log scale is. There is a reason for that: exponential phenomena are well suited for plotting on log scales, where an exponential propagation becomes a straight line. You wouldn't want to miss out on this centuries-old fad:

# %%
ax=timeseriesdf.plot(logy=True) # ...lemon squeezy
ax.set_title('Daily cases, hospital admissions and deaths (log scale)');

# %% [markdown]
# ## Lineage data

# %% [markdown]
# As a second example, let's lineage data. The data scructure, as you can see, is a bit different, so this will be another good exercise in data wrangling.

# %%
with open("lineage.json", "rt") as INFILE:
    lineage=json.load(INFILE)

# %%
lineage[:5]
# Out:
# [{'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_lineagePercentByWeek',
#   'metric_group': 'cases',
#   'stratum': 'Omicron BA.5',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2021,
#   'month': 1,
#   'epiweek': 1,
#   'date': '2021-01-04',
#   'metric_value': 0.01,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_lineagePercentByWeek',
#   'metric_group': 'cases',
#   'stratum': 'Alpha',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2021,
#   'month': 1,
#   'epiweek': 1,
#   'date': '2021-01-04',
#   'metric_value': 81.59,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_lineagePercentByWeek',
#   'metric_group': 'cases',
#   'stratum': 'Delta',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2021,
#   'month': 1,
#   'epiweek': 1,
#   'date': '2021-01-04',
#   'metric_value': 0.03,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_lineagePercentByWeek',
#   'metric_group': 'cases',
#   'stratum': 'Omicron BA.1',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2021,
#   'month': 1,
#   'epiweek': 1,
#   'date': '2021-01-04',
#   'metric_value': 0.22,
#   'in_reporting_delay_period': False},
#  {'theme': 'infectious_disease',
#   'sub_theme': 'respiratory',
#   'topic': 'COVID-19',
#   'geography_type': 'Nation',
#   'geography': 'England',
#   'geography_code': 'E92000001',
#   'metric': 'COVID-19_cases_lineagePercentByWeek',
#   'metric_group': 'cases',
#   'stratum': 'Other',
#   'sex': 'all',
#   'age': 'all',
#   'year': 2021,
#   'month': 1,
#   'epiweek': 1,
#   'date': '2021-01-04',
#   'metric_value': 18.15,
#   'in_reporting_delay_period': False}]

# %% [markdown]
# ### Data munging

# %% [markdown]
# Once again, there are no fixed rules for this - just see in what format your data comes, have clear in your mind what you are aiming for, and wrangle your data accordingly. In this case, we again want to get to a ```DataFrame``` with the dates as the *index*, and the prevalence of the different variants as its *columns*.
#
# In this case, the fields of interest out of this series are ```date```, ```stratum``` and ```metric_value```. Notice also that for each ```date``` there are several entries, one for each variant represented in that period. Let us again try to organise the data into a dictionary of dictionaries, with the dates as keys:

# %%
data={}
for entry in lineage:
    date=entry['date']
    variant=entry['stratum']
    value=entry['metric_value']
    if date not in data:
        data[date]={}
    data[date][variant]=value

# %%
data
# Out:
# {'2021-01-04': {'Omicron BA.5': 0.01,
#   'Alpha': 81.59,
#   'Delta': 0.03,
#   'Omicron BA.1': 0.22,
#   'Other': 18.15},
#  '2021-01-11': {'Omicron BA.1': 0.09,
#   'Alpha': 83.97,
#   'Delta': 0.02,
#   'Omicron BA.2': 0.01,
#   'Other': 15.92},
#  '2021-01-18': {'Alpha': 88.68,
#   'Delta': 0.04,
#   'Other': 11.26,
#   'Omicron BA.1': 0.02},
#  '2021-01-25': {'Omicron BA.5': 0.01,
#   'Alpha': 93.54,
#   'Other': 6.42,
#   'Delta': 0.02,
#   'Omicron BA.1': 0.01},
#  '2021-02-01': {'Alpha': 95.18,
#   'Omicron BA.5': 0.01,
#   'Omicron BA.1': 0.04,
#   'Delta': 0.01,
#   'Other': 4.77},
#  '2021-02-08': {'Delta': 0.01, 'Other': 3.28, 'Alpha': 96.71},
#  '2021-02-15': {'Alpha': 97.34, 'Other': 2.65, 'Delta': 0.01},
#  '2021-02-22': {'Other': 2.72,
#   'Alpha': 97.26,
#   'Omicron BA.1': 0.01,
#   'Delta': 0.01},
#  '2021-03-01': {'Delta': 0.04,
#   'Omicron BA.1': 0.01,
#   'Other': 3.19,
#   'Alpha': 96.77},
#  '2021-03-08': {'Other': 2.56, 'Delta': 0.01, 'Alpha': 97.42},
#  '2021-03-15': {'Other': 2.14,
#   'Omicron BA.1': 0.01,
#   'Delta': 0.06,
#   'Alpha': 97.8},
#  '2021-03-22': {'Delta': 0.16,
#   'Alpha': 97.92,
#   'Omicron BA.2': 0.01,
#   'Other': 1.92},
#  '2021-03-29': {'Other': 2.37, 'Alpha': 97.35, 'Delta': 0.28},
#  '2021-04-05': {'Other': 3.18, 'Alpha': 95.35, 'Delta': 1.46},
#  '2021-04-12': {'Other': 3.9,
#   'Delta': 3.23,
#   'Omicron BA.1': 0.02,
#   'Alpha': 92.86},
#  '2021-04-19': {'Other': 4.14, 'Alpha': 88.22, 'Delta': 7.63},
#  '2021-04-26': {'Other': 3.57,
#   'Omicron BA.1': 0.03,
#   'Alpha': 82.1,
#   'Delta': 14.3},
#  '2021-05-03': {'Delta': 27.57, 'Alpha': 69.34, 'Other': 3.1},
#  '2021-05-10': {'Delta': 44.83, 'Alpha': 52.83, 'Other': 2.34},
#  '2021-05-17': {'Other': 1.51,
#   'Alpha': 32.85,
#   'Delta': 65.63,
#   'Omicron BA.1': 0.01},
#  '2021-05-24': {'Delta': 82.11, 'Other': 0.9, 'Alpha': 16.99},
#  '2021-05-31': {'Delta': 91.1, 'Other': 0.4, 'Alpha': 8.48},
#  '2021-06-07': {'Alpha': 4.22, 'Other': 0.34, 'Delta': 95.44},
#  '2021-06-14': {'Alpha': 1.46, 'Delta': 98.36, 'Other': 0.19},
#  '2021-06-21': {'Alpha': 0.94, 'Other': 0.22, 'Delta': 98.83},
#  '2021-06-28': {'Alpha': 0.52, 'Delta': 99.32, 'Other': 0.16},
#  '2021-07-05': {'Alpha': 0.21,
#   'Other': 0.23,
#   'Omicron BA.1': 0.01,
#   'Omicron BA.5': 0.0,
#   'Delta': 99.55},
#  '2021-07-12': {'Alpha': 0.08, 'Delta': 99.65, 'Other': 0.27},
#  '2021-07-19': {'Omicron BA.2': 0.0,
#   'Omicron BA.1': 0.01,
#   'Delta': 99.66,
#   'Alpha': 0.07,
#   'Other': 0.26},
#  '2021-07-26': {'Delta': 99.8,
#   'Omicron BA.1': 0.01,
#   'Alpha': 0.04,
#   'Other': 0.16},
#  '2021-08-02': {'Omicron BA.1': 0.01,
#   'Other': 0.37,
#   'Delta': 99.58,
#   'Alpha': 0.03},
#  '2021-08-09': {'Delta': 98.44,
#   'Alpha': 0.01,
#   'Omicron BA.1': 0.02,
#   'Other': 1.52},
#  '2021-08-16': {'Other': 0.18,
#   'Alpha': 0.01,
#   'Omicron BA.1': 0.01,
#   'Delta': 99.79,
#   'Omicron BA.5': 0.0},
#  '2021-08-23': {'Other': 0.09,
#   'Alpha': 0.02,
#   'Delta': 99.88,
#   'Omicron BA.1': 0.02},
#  '2021-08-30': {'Omicron BA.1': 0.03,
#   'Other': 0.12,
#   'Alpha': 0.0,
#   'Omicron BA.2': 0.0,
#   'Delta': 99.84},
#  '2021-09-06': {'Omicron BA.2': 0.0,
#   'Omicron BA.1': 0.04,
#   'Delta': 99.83,
#   'Other': 0.12,
#   'Alpha': 0.01},
#  '2021-09-13': {'Alpha': 0.02,
#   'Other': 0.09,
#   'Omicron BA.2': 0.0,
#   'Omicron BA.1': 0.11,
#   'Delta': 99.78},
#  '2021-09-20': {'Omicron BA.1': 0.19,
#   'Other': 0.03,
#   'Delta': 99.76,
#   'Omicron BA.2': 0.0,
#   'Alpha': 0.01},
#  '2021-09-27': {'Other': 0.09,
#   'Delta': 99.55,
#   'Omicron BA.2': 0.02,
#   'Omicron BA.1': 0.34},
#  '2021-10-04': {'Omicron BA.2': 0.02,
#   'Omicron BA.1': 0.57,
#   'Other': 0.12,
#   'Alpha': 0.01,
#   'Delta': 99.28},
#  '2021-10-11': {'Omicron BA.1': 1.12,
#   'Omicron BA.2': 0.03,
#   'Alpha': 0.01,
#   'Other': 0.13,
#   'Delta': 98.71},
#  '2021-10-18': {'Omicron BA.1': 1.22,
#   'Omicron BA.2': 0.03,
#   'Other': 0.1,
#   'Alpha': 0.01,
#   'Delta': 98.64},
#  '2021-10-25': {'Other': 0.09,
#   'Omicron BA.1': 1.17,
#   'Omicron BA.2': 0.05,
#   'Delta': 98.68,
#   'Alpha': 0.0},
#  '2021-11-01': {'Other': 0.05,
#   'Omicron BA.1': 1.21,
#   'Omicron BA.2': 0.08,
#   'Delta': 98.67},
#  '2021-11-08': {'Omicron BA.2': 0.17,
#   'Delta': 98.47,
#   'Other': 0.08,
#   'Omicron BA.1': 1.28},
#  '2021-11-15': {'Other': 0.09,
#   'Omicron BA.2': 0.23,
#   'Delta': 98.24,
#   'Omicron BA.1': 1.45},
#  '2021-11-22': {'Delta': 97.94,
#   'Other': 0.07,
#   'Omicron BA.1': 1.68,
#   'Omicron BA.5': 0.0,
#   'Omicron BA.2': 0.31},
#  '2021-11-29': {'Other': 0.09,
#   'Omicron BA.2': 0.43,
#   'Omicron BA.1': 3.29,
#   'Delta': 96.18},
#  '2021-12-06': {'Other': 0.2,
#   'Delta': 78.75,
#   'Omicron BA.2': 0.65,
#   'Omicron BA.1': 20.4},
#  '2021-12-13': {'Delta': 34.91,
#   'Omicron BA.1': 63.98,
#   'Omicron BA.4': 0.0,
#   'Omicron BA.2': 0.79,
#   'Omicron BA.5': 0.02,
#   'Other': 0.29},
#  '2021-12-20': {'Omicron BA.1': 84.77,
#   'Omicron BA.5': 0.0,
#   'Other': 0.33,
#   'Alpha': 0.0,
#   'Omicron BA.2': 1.35,
#   'Delta': 13.55},
#  '2021-12-27': {'Delta': 3.91,
#   'Alpha': 0.0,
#   'Omicron BA.5': 0.01,
#   'Omicron BA.1': 94.42,
#   'Omicron BA.4': 0.0,
#   'Omicron BA.2': 1.36,
#   'Other': 0.3},
#  '2022-01-03': {'Omicron BA.5': 0.01,
#   'Delta': 1.83,
#   'Omicron BA.1': 96.08,
#   'Omicron BA.4': 0.0,
#   'Other': 0.35,
#   'Omicron BA.2.75': 0.0,
#   'Omicron BA.2': 1.72,
#   'Alpha': 0.0},
#  '2022-01-10': {'Omicron BA.1': 96.18,
#   'Omicron BA.5': 0.01,
#   'Delta': 0.72,
#   'Other': 0.24,
#   'Omicron BA.2': 2.85},
#  '2022-01-17': {'Omicron BA.2': 4.67,
#   'Delta': 0.29,
#   'Other': 0.25,
#   'Omicron BA.5': 0.01,
#   'Omicron BA.4': 0.0,
#   'Omicron BA.1': 94.78},
#  '2022-01-24': {'Delta': 0.09,
#   'Omicron BA.5': 0.01,
#   'Other': 0.18,
#   'Omicron BA.2': 9.2,
#   'Omicron BA.4': 0.0,
#   'Omicron BA.1': 90.52},
#  '2022-01-31': {'Omicron XBB': 0.0,
#   'Omicron BA.4': 0.0,
#   'Omicron BA.1': 83.28,
#   'Omicron BA.2': 16.36,
#   'Omicron BA.5': 0.01,
#   'Delta': 0.06,
#   'Other': 0.28,
#   'Alpha': 0.0},
#  '2022-02-07': {'Omicron BA.5': 0.01,
#   'Other': 0.31,
#   'Omicron BA.2': 26.11,
#   'Omicron BA.1': 73.53,
#   'Delta': 0.04},
#  '2022-02-14': {'Delta': 0.04,
#   'Omicron BA.1': 56.36,
#   'Omicron BA.4': 0.0,
#   'Omicron BA.5': 0.01,
#   'Omicron BA.2': 43.3,
#   'Other': 0.29},
#  '2022-02-21': {'Omicron BA.5': 0.02,
#   'Delta': 0.02,
#   'Omicron BA.1': 40.45,
#   'Omicron BA.2': 59.06,
#   'Other': 0.45,
#   'Omicron BA.4': 0.0},
#  '2022-02-28': {'Delta': 0.01,
#   'Omicron BA.5': 0.01,
#   'Other': 0.43,
#   'Omicron BA.1': 23.9,
#   'Omicron BA.2': 75.65,
#   'Omicron BA.4': 0.0},
#  '2022-03-07': {'Omicron BA.1': 14.16,
#   'Omicron BA.5': 0.01,
#   'Omicron BA.2': 85.22,
#   'Delta': 0.01,
#   'Other': 0.6},
#  '2022-03-14': {'Delta': 0.01,
#   'Omicron BA.2': 91.16,
#   'Omicron BA.5': 0.02,
#   'Other': 0.63,
#   'Omicron BA.1': 8.17,
#   'Omicron BA.4': 0.01},
#  '2022-03-21': {'Other': 0.71,
#   'Omicron BA.2': 94.74,
#   'Delta': 0.01,
#   'Omicron BA.4': 0.02,
#   'Omicron BA.1': 4.48,
#   'Omicron BA.5': 0.05},
#  '2022-03-28': {'Other': 0.81,
#   'Omicron BA.1': 3.14,
#   'Omicron BA.4': 0.06,
#   'Omicron BA.5': 0.11,
#   'Omicron BA.2': 95.88},
#  '2022-04-04': {'Other': 0.86,
#   'Omicron BA.5': 0.22,
#   'Omicron BA.4': 0.14,
#   'Delta': 0.01,
#   'Omicron BA.2': 96.79,
#   'Omicron BA.1': 1.98},
#  '2022-04-11': {'Omicron BA.2': 97.43,
#   'Omicron BA.4': 0.13,
#   'Other': 0.94,
#   'Omicron BA.1': 1.19,
#   'Omicron BA.5': 0.31},
#  '2022-04-18': {'Omicron BA.4': 0.19,
#   'Other': 1.21,
#   'Omicron BA.1': 0.79,
#   'Omicron BA.2': 97.22,
#   'Omicron BA.5': 0.57,
#   'Alpha': 0.01},
#  '2022-04-25': {'Other': 1.7,
#   'Omicron BA.2': 96.27,
#   'Omicron BA.4': 0.67,
#   'Omicron BA.1': 0.47,
#   'Omicron BA.5': 0.88},
#  '2022-05-02': {'Other': 1.23,
#   'Omicron BA.5': 1.74,
#   'Omicron BA.2': 95.06,
#   'Omicron BA.1': 0.32,
#   'Omicron BA.4': 1.65},
#  '2022-05-09': {'Omicron BA.2': 91.18,
#   'Omicron BA.5': 3.42,
#   'Other': 1.45,
#   'Omicron BA.4': 3.61,
#   'Omicron BA.1': 0.34},
#  '2022-05-16': {'Omicron BA.5': 7.43,
#   'Omicron BA.2': 84.82,
#   'Other': 1.77,
#   'Omicron BA.1': 0.21,
#   'Omicron BA.4': 5.77},
#  '2022-05-23': {'Omicron BA.1': 0.04,
#   'Omicron BA.4': 9.09,
#   'Omicron BA.2': 73.28,
#   'Other': 1.13,
#   'Omicron BA.5': 16.45},
#  '2022-05-30': {'Omicron BA.4': 15.64,
#   'Omicron BA.5': 28.93,
#   'Other': 1.01,
#   'Omicron BA.2': 54.32,
#   'Delta': 0.03,
#   'Omicron BA.1': 0.07},
#  '2022-06-06': {'Delta': 0.04,
#   'Other': 1.62,
#   'Omicron BA.2': 35.9,
#   'Omicron BA.4': 19.51,
#   'Omicron BA.5': 42.9,
#   'Omicron BA.1': 0.04},
#  '2022-06-13': {'Omicron BA.1': 0.06,
#   'Omicron BA.4': 20.89,
#   'Omicron BA.2': 22.81,
#   'Omicron BA.2.75': 0.02,
#   'Other': 1.57,
#   'Omicron BA.5': 54.65},
#  '2022-06-20': {'Omicron BA.5': 64.84,
#   'Other': 1.77,
#   'Omicron BA.4': 19.69,
#   'Omicron BA.1': 0.03,
#   'Omicron BA.2': 13.58,
#   'Omicron BA.2.75': 0.1},
#  '2022-06-27': {'Omicron BA.4': 19.51,
#   'Omicron BA.1': 0.01,
#   'Omicron BA.2.75': 0.04,
#   'Other': 1.65,
#   'Delta': 0.01,
#   'Omicron BA.5': 71.43,
#   'Omicron BA.2': 7.34},
#  '2022-07-04': {'Omicron BA.2.75': 0.04,
#   'Omicron BA.2': 4.62,
#   'Omicron BA.1': 0.02,
#   'Omicron BA.5': 77.88,
#   'Other': 1.64,
#   'Omicron BA.4': 15.8},
#  '2022-07-11': {'Omicron BA.5': 80.62,
#   'Delta': 0.02,
#   'Omicron BA.4': 15.02,
#   'Omicron BA.1': 0.01,
#   'Omicron BA.2': 2.44,
#   'Omicron BA.2.75': 0.06,
#   'Other': 1.82},
#  '2022-07-18': {'Other': 1.08,
#   'Omicron BA.4': 13.13,
#   'Omicron BA.5': 84.17,
#   'Omicron BA.2': 1.49,
#   'Omicron BA.1': 0.03,
#   'Omicron BA.2.75': 0.1},
#  '2022-07-25': {'Omicron BA.4': 12.09,
#   'Other': 1.52,
#   'Omicron BA.2': 1.13,
#   'Omicron BA.2.75': 0.09,
#   'Omicron BA.5': 85.17},
#  '2022-08-01': {'Omicron BA.2.75': 0.33,
#   'Omicron BA.4': 12.49,
#   'Other': 1.36,
#   'Omicron BA.5': 85.06,
#   'Omicron BA.1': 0.02,
#   'Omicron BA.2': 0.74},
#  '2022-08-08': {'Omicron XBB': 0.02,
#   'Other': 1.68,
#   'Omicron BA.5': 87.27,
#   'Omicron BA.2.75': 0.62,
#   'Omicron BA.1': 0.02,
#   'Omicron BA.4': 10.13,
#   'Omicron BA.2': 0.26},
#  '2022-08-15': {'Omicron BA.2.75': 0.72,
#   'Omicron BA.5': 87.18,
#   'Omicron BA.4': 8.73,
#   'Other': 2.55,
#   'Omicron BA.2': 0.79,
#   'Omicron BA.1': 0.03},
#  '2022-08-22': {'Other': 2.51,
#   'Omicron BA.4': 9.13,
#   'Omicron BA.2.75': 1.15,
#   'Omicron BA.2': 0.29,
#   'Omicron BA.5': 86.92},
#  '2022-08-29': {'Omicron BA.2': 0.32,
#   'Omicron BA.2.75': 1.44,
#   'Omicron BA.4': 9.19,
#   'Omicron BA.5': 88.04,
#   'Omicron BA.1': 0.04,
#   'Other': 0.96},
#  '2022-09-05': {'Omicron BA.5': 86.22,
#   'Omicron BA.1': 0.04,
#   'Omicron BA.4': 9.12,
#   'Omicron XBB': 0.04,
#   'Omicron BA.2.75': 2.65,
#   'Omicron BA.2': 0.44,
#   'Other': 1.49},
#  '2022-09-12': {'Other': 1.15,
#   'Omicron BA.2.75': 4.15,
#   'Omicron BA.2': 0.29,
#   'Omicron XBB': 0.07,
#   'Omicron BA.5': 87.18,
#   'Omicron BA.1': 0.04,
#   'Omicron BA.4': 7.13},
#  '2022-09-19': {'Omicron BA.2.75': 5.28,
#   'Other': 1.6,
#   'Omicron XBB': 0.1,
#   'Omicron BA.5': 86.34,
#   'Omicron BA.1': 0.05,
#   'Omicron BA.4': 6.37,
#   'Omicron BA.2': 0.27},
#  '2022-09-26': {'Omicron BA.4': 5.58,
#   'Omicron BA.2.75': 4.19,
#   'Omicron XBB': 0.25,
#   'Omicron BA.2': 0.37,
#   'Omicron BA.5': 87.86,
#   'Omicron BA.1': 0.04,
#   'Other': 1.71},
#  '2022-10-03': {'Omicron BA.2': 0.56,
#   'Other': 2.16,
#   'Omicron BA.2.75': 5.32,
#   'Omicron BA.1': 0.01,
#   'Omicron XBB': 0.32,
#   'Omicron BA.5': 86.5,
#   'Omicron BA.4': 5.12},
#  '2022-10-10': {'Omicron BA.2.75': 5.21,
#   'Omicron XBB': 0.69,
#   'Omicron BA.4': 4.67,
#   'Omicron BA.2': 0.39,
#   'Other': 1.76,
#   'Omicron BA.5': 87.28},
#  '2022-10-17': {'Omicron BA.1': 0.06,
#   'Omicron BA.2': 1.09,
#   'Omicron XBB': 1.27,
#   'Omicron BA.2.75': 6.71,
#   'Omicron BA.4': 3.88,
#   'Other': 1.31,
#   'Omicron BA.5': 85.68},
#  '2022-10-24': {'Omicron BA.2': 1.16,
#   'Omicron BA.2.75': 8.52,
#   'Omicron BA.4': 3.35,
#   'Omicron XBB': 1.32,
#   'Other': 1.32,
#   'Omicron BA.1': 0.03,
#   'Omicron BA.5': 84.31},
#  '2022-10-31': {'Omicron BA.5': 84.67,
#   'Omicron BA.2': 1.44,
#   'Omicron BA.1': 0.04,
#   'Omicron BA.2.75': 7.86,
#   'Omicron BA.4': 2.48,
#   'Delta': 0.04,
#   'Other': 1.33,
#   'Omicron XBB': 2.15},
#  '2022-11-07': {'Omicron XBB': 3.65,
#   'Omicron BA.2.75': 10.43,
#   'Other': 0.96,
#   'Omicron BA.5': 80.18,
#   'Omicron BA.2': 2.37,
#   'Omicron BA.4': 2.41},
#  '2022-11-14': {'Other': 1.29,
#   'Omicron BA.5': 80.94,
#   'Omicron XBB': 3.83,
#   'Omicron BA.4': 1.37,
#   'Omicron BA.2.75': 9.55,
#   'Omicron BA.2': 3.02},
#  '2022-11-21': {'Omicron BA.2': 7.09,
#   'Other': 1.11,
#   'Omicron BA.4': 1.41,
#   'Omicron XBB': 4.77,
#   'Omicron BA.5': 76.19,
#   'Omicron BA.1': 0.03,
#   'Omicron BA.2.75': 9.38},
#  '2022-11-28': {'Omicron BA.2.75': 9.46,
#   'Other': 0.85,
#   'Omicron BA.4': 0.99,
#   'Omicron BA.2': 7.65,
#   'Omicron XBB': 4.74,
#   'Omicron BA.5': 76.31},
#  '2022-12-05': {'Omicron BA.4': 0.66,
#   'Omicron BA.1': 0.02,
#   'Omicron BA.2.75': 9.26,
#   'Other': 1.03,
#   'Omicron XBB': 5.09,
#   'Omicron BA.2': 10.58,
#   'Omicron BA.5': 73.36},
#  '2022-12-12': {'Omicron BA.5': 70.17,
#   'Omicron BA.1': 0.02,
#   'Omicron BA.2': 14.24,
#   'Omicron BA.2.75': 7.66,
#   'Omicron BA.4': 0.63,
#   'Omicron XBB': 5.85,
#   'Other': 1.43},
#  '2022-12-19': {'Omicron BA.5': 66.93,
#   'Omicron BA.2': 17.58,
#   'Omicron XBB': 6.39,
#   'Other': 1.69,
#   'Omicron BA.2.75': 6.83,
#   'Omicron BA.1': 0.03,
#   'Omicron BA.4': 0.55},
#  '2022-12-26': {'Other': 1.6,
#   'Omicron XBB': 8.88,
#   'Omicron BA.2.75': 7.58,
#   'Omicron BA.2': 22.59,
#   'Omicron BA.4': 0.39,
#   'Omicron BA.5': 58.95,
#   'Delta': 0.02},
#  '2023-01-02': {'Omicron BA.5': 55.8,
#   'Other': 1.69,
#   'Omicron BA.4': 0.57,
#   'Omicron BA.2.75': 8.45,
#   'Omicron BA.1': 0.02,
#   'Omicron XBB': 8.56,
#   'Omicron BA.2': 24.92},
#  '2023-01-09': {'Omicron XBB': 11.65,
#   'Omicron BA.2.75': 6.34,
#   'Other': 1.96,
#   'Omicron BA.2': 26.54,
#   'Omicron BA.4': 0.55,
#   'Omicron BA.1': 0.03,
#   'Omicron BA.5': 52.91},
#  '2023-01-16': {'Omicron BA.2.75': 5.87,
#   'Omicron BA.4': 0.27,
#   'Omicron BA.5': 47.24,
#   'Omicron BA.2': 27.73,
#   'Omicron XBB': 17.69,
#   'Other': 1.2},
#  '2023-01-23': {'Omicron BA.5': 40.61,
#   'Omicron BA.2.75': 4.63,
#   'Other': 0.99,
#   'Omicron XBB': 21.5,
#   'Omicron BA.2': 32.07,
#   'Omicron BA.4': 0.2},
#  '2023-01-30': {'Omicron BA.2': 29.11,
#   'Other': 0.9,
#   'Omicron BA.5': 35.88,
#   'Omicron XBB': 31.25,
#   'Omicron BA.4': 0.11,
#   'Omicron BA.2.75': 2.75},
#  '2023-02-06': {'Omicron BA.2.75': 2.99,
#   'Other': 1.7,
#   'Omicron BA.5': 24.28,
#   'Omicron BA.2': 28.08,
#   'Omicron BA.4': 0.07,
#   'Omicron XBB': 42.88},
#  '2023-02-13': {'Other': 1.66,
#   'Omicron BA.2': 24.55,
#   'Omicron BA.2.75': 2.35,
#   'Omicron XBB': 48.25,
#   'Omicron BA.5': 23.19},
#  '2023-02-20': {'Other': 1.56,
#   'Omicron BA.2': 23.64,
#   'Omicron BA.5': 16.14,
#   'Omicron BA.2.75': 1.56,
#   'Omicron BA.4': 0.02,
#   'Omicron XBB': 57.09},
#  '2023-02-27': {'Other': 1.08,
#   'Omicron BA.2.75': 1.19,
#   'Omicron XBB': 63.86,
#   'Omicron BA.5': 11.91,
#   'Omicron BA.2': 21.95},
#  '2023-03-06': {'Omicron XBB': 71.53,
#   'Omicron BA.5': 9.4,
#   'Other': 1.6,
#   'Omicron BA.2.75': 1.22,
#   'Omicron BA.2': 16.24},
#  '2023-03-13': {'Omicron BA.2': 14.4,
#   'Omicron BA.5': 7.74,
#   'Omicron XBB': 75.08,
#   'Omicron BA.2.75': 1.56,
#   'Other': 1.22},
#  '2023-03-20': {'Other': 1.22,
#   'Omicron BA.2.75': 1.31,
#   'Omicron XBB': 79.13,
#   'Omicron BA.5': 6.77,
#   'Omicron BA.2': 11.56},
#  '2023-03-27': {'Omicron BA.2': 10.96,
#   'Other': 1.11,
#   'Omicron BA.5': 4.97,
#   'Omicron BA.2.75': 1.15,
#   'Omicron XBB': 81.81},
#  '2023-04-03': {'Other': 1.16,
#   'Omicron BA.2.75': 1.32,
#   'Omicron XBB': 82.96,
#   'Omicron BA.5': 3.72,
#   'Omicron BA.2': 10.84},
#  '2023-04-10': {'Delta': 0.08,
#   'Omicron XBB': 88.23,
#   'Other': 1.08,
#   'Omicron BA.5': 1.69,
#   'Omicron BA.2.75': 0.38,
#   'Omicron BA.2': 8.54},
#  '2023-04-17': {'Other': 0.73,
#   'Omicron XBB': 89.19,
#   'Omicron BA.2.75': 1.01,
#   'Omicron BA.2': 7.51,
#   'Omicron BA.5': 1.56},
#  '2023-04-24': {'Omicron BA.5': 0.49,
#   'Omicron XBB': 91.21,
#   'Other': 1.68,
#   'Omicron BA.2.86': 0.1,
#   'Omicron BA.2.75': 0.89,
#   'Omicron BA.2': 5.63},
#  '2023-05-01': {'Omicron XBB': 93.76,
#   'Omicron BA.5': 0.45,
#   'Other': 1.34,
#   'Omicron BA.2': 4.46},
#  '2023-05-08': {'Omicron BA.2': 4.12,
#   'Omicron XBB': 94.36,
#   'Omicron BA.2.75': 0.15,
#   'Omicron BA.5': 0.3,
#   'Other': 1.07},
#  '2023-05-15': {'Other': 0.77,
#   'Omicron XBB': 94.48,
#   'Omicron BA.4': 0.15,
#   'Omicron BA.2': 3.99,
#   'Omicron BA.5': 0.31,
#   'Omicron BA.2.75': 0.31},
#  '2023-05-22': {'Other': 0.81,
#   'Omicron XBB': 94.56,
#   'Omicron BA.2': 3.83,
#   'Omicron BA.2.75': 0.4,
#   'Omicron BA.5': 0.4},
#  '2023-05-29': {'Other': 1.84,
#   'Omicron BA.2': 1.84,
#   'Omicron BA.5': 0.23,
#   'Omicron BA.2.75': 0.23,
#   'Omicron XBB': 95.86},
#  '2023-06-05': {'Other': 1.11,
#   'Omicron BA.2.75': 0.28,
#   'Omicron BA.2': 3.6,
#   'Omicron XBB': 94.18,
#   'Omicron BA.5': 0.83},
#  '2023-06-12': {'Other': 1.3,
#   'Omicron BA.2': 1.3,
#   'Omicron XBB': 96.54,
#   'Omicron BA.5': 0.87},
#  '2023-06-19': {'Omicron BA.5': 0.5,
#   'Omicron BA.2': 2.0,
#   'Omicron BA.1': 0.5,
#   'Omicron BA.2.86': 1.0,
#   'Other': 1.0,
#   'Omicron XBB': 95.0},
#  '2023-06-26': {'Omicron JN.1': 0.66,
#   'Other': 1.33,
#   'Omicron BA.2': 2.67,
#   'Omicron BA.5': 0.67,
#   'Omicron XBB': 95.36},
#  '2023-07-03': {'Omicron BA.5': 0.46,
#   'Omicron XBB': 96.76,
#   'Other': 0.46,
#   'Omicron BA.2': 2.31},
#  '2023-07-10': {'Other': 0.39,
#   'Omicron BA.5': 0.78,
#   'Omicron XBB': 96.09,
#   'Omicron BA.2': 2.73},
#  '2023-07-17': {'Omicron XBB': 97.42,
#   'Omicron BA.2': 2.29,
#   'Omicron BA.5': 0.29},
#  '2023-07-24': {'Other': 0.87,
#   'Omicron BA.2': 2.38,
#   'Omicron BA.2.75': 0.22,
#   'Omicron XBB': 96.54,
#   'Omicron JN.1': 0.22},
#  '2023-07-31': {'Other': 0.31,
#   'Omicron BA.2.86': 0.16,
#   'Omicron BA.5': 0.16,
#   'Omicron XBB': 97.8,
#   'Omicron BA.2': 1.57},
#  '2023-08-07': {'Omicron XBB': 96.97,
#   'Omicron BA.5': 0.15,
#   'Omicron BA.2.86': 0.15,
#   'Other': 0.3,
#   'Omicron BA.2': 2.42},
#  '2023-08-14': {'Omicron XBB': 96.75,
#   'Other': 0.57,
#   'Omicron BA.2': 1.98,
#   'Omicron BA.2.86': 0.28,
#   'Omicron BA.5': 0.42},
#  '2023-08-21': {'Omicron BA.5': 0.37,
#   'Omicron BA.2.75': 0.12,
#   'Other': 0.73,
#   'Omicron BA.2': 2.56,
#   'Omicron XBB': 92.32,
#   'Omicron BA.2.86': 3.9},
#  '2023-08-28': {'Omicron BA.5': 0.22,
#   'Omicron XBB': 96.97,
#   'Omicron JN.1': 0.11,
#   'Other': 0.32,
#   'Omicron BA.2.86': 0.76,
#   'Omicron BA.2': 1.62},
#  '2023-09-04': {'Omicron BA.5': 0.08,
#   'Omicron BA.2.86': 1.08,
#   'Omicron BA.2': 1.94,
#   'Omicron XBB': 96.13,
#   'Other': 0.77},
#  '2023-09-11': {'Omicron JN.1': 0.09,
#   'Omicron BA.5': 0.18,
#   'Other': 1.19,
#   'Omicron XBB': 95.05,
#   'Omicron BA.2.86': 1.19,
#   'Omicron BA.2': 2.29},
#  '2023-09-18': {'Omicron BA.2': 1.48,
#   'Omicron BA.2.86': 1.78,
#   'Other': 0.89,
#   'Omicron XBB': 95.7,
#   'Omicron JN.1': 0.07,
#   'Omicron BA.5': 0.07},
#  '2023-09-25': {'Omicron BA.5': 0.13,
#   'Omicron XBB': 93.81,
#   'Omicron BA.2.86': 2.61,
#   'Omicron BA.2': 2.61,
#   'Omicron JN.1': 0.26,
#   'Other': 0.59},
#  '2023-10-02': {'Omicron BA.5': 0.28,
#   'Omicron JN.1': 0.33,
#   'Omicron BA.1': 0.06,
#   'Other': 0.88,
#   'Omicron BA.2.86': 3.21,
#   'Omicron XBB': 92.87,
#   'Omicron BA.2': 2.38},
#  '2023-10-09': {'Omicron XBB': 92.12,
#   'Omicron JN.1': 0.14,
#   'Omicron BA.2.86': 4.25,
#   'Omicron BA.2': 2.58,
#   'Omicron BA.5': 0.07,
#   'Other': 0.84},
#  '2023-10-16': {'Omicron XBB': 89.45,
#   'Omicron BA.2.86': 6.55,
#   'Omicron JN.1': 0.94,
#   'Omicron BA.2': 2.04,
#   'Other': 1.02},
#  '2023-10-23': {'Other': 0.8,
#   'Omicron BA.5': 0.09,
#   'Omicron JN.1': 1.69,
#   'Omicron BA.2.86': 10.41,
#   'Omicron XBB': 85.68,
#   'Omicron BA.2': 1.33},
#  '2023-10-30': {'Omicron JN.1': 2.52,
#   'Omicron BA.2.86': 12.08,
#   'Omicron XBB': 83.27,
#   'Omicron BA.2': 0.8,
#   'Other': 1.33},
#  '2023-11-06': {'Omicron JN.1': 5.78,
#   'Omicron BA.2': 1.27,
#   'Omicron BA.2.86': 10.16,
#   'Omicron XBB': 81.52,
#   'Other': 1.27},
#  '2023-11-13': {'Omicron BA.2.86': 13.95,
#   'Omicron BA.5': 0.15,
#   'Omicron BA.2': 0.59,
#   'Omicron JN.1': 12.63,
#   'Other': 2.2,
#   'Omicron BA.4': 0.15,
#   'Omicron XBB': 70.34},
#  '2023-11-20': {'Omicron BA.5': 0.15,
#   'Omicron JN.1': 19.11,
#   'Omicron BA.2.86': 18.8,
#   'Omicron BA.2': 1.23,
#   'Omicron XBB': 58.71,
#   'Other': 2.0},
#  '2023-11-27': {'Omicron XBB': 51.12,
#   'Other': 1.61,
#   'Omicron BA.2.86': 19.35,
#   'Omicron JN.1': 26.67,
#   'Omicron BA.2.75': 0.12,
#   'Omicron BA.2': 1.12},
#  '2023-12-04': {'Omicron XBB': 37.63,
#   'Omicron BA.2': 1.24,
#   'Omicron BA.2.86': 20.35,
#   'Omicron JN.1': 39.04,
#   'Other': 1.74},
#  '2023-12-11': {'Omicron BA.2.86': 22.25,
#   'Omicron BA.2.75': 0.07,
#   'Omicron BA.2': 1.75,
#   'Omicron JN.1': 44.35,
#   'Other': 0.8,
#   'Omicron XBB': 30.78},
#  '2023-12-18': {'Other': 1.58,
#   'Omicron BA.2': 1.99,
#   'Omicron XBB': 25.29,
#   'Omicron JN.1': 55.11,
#   'Omicron BA.2.86': 16.04},
#  '2023-12-25': {'Other': 2.16,
#   'Omicron JN.1': 62.64,
#   'Omicron BA.2.86': 16.34,
#   'Omicron BA.2': 1.33,
#   'Omicron XBB': 17.46,
#   'Omicron BA.4': 0.07},
#  '2024-01-01': {'Omicron JN.1': 69.87,
#   'Other': 2.76,
#   'Omicron BA.2': 1.56,
#   'Omicron BA.2.86': 12.09,
#   'Omicron XBB': 13.72},
#  '2024-01-08': {'Omicron BA.2': 2.27,
#   'Omicron XBB': 8.98,
#   'Omicron BA.2.86': 10.79,
#   'Other': 4.62,
#   'Omicron JN.1': 73.35},
#  '2024-01-15': {'Omicron JN.1': 79.02,
#   'Omicron BA.2': 2.54,
#   'Other': 4.33,
#   'Omicron BA.2.86': 9.03,
#   'Omicron XBB': 5.08},
#  '2024-01-22': {'Other': 4.32,
#   'Omicron XBB': 3.85,
#   'Omicron JN.1': 82.65,
#   'Omicron BA.4': 0.08,
#   'Omicron BA.2.86': 6.51,
#   'Omicron BA.2': 2.59},
#  '2024-01-29': {'Omicron BA.2': 2.8,
#   'Omicron XBB': 3.0,
#   'Omicron BA.2.86': 6.18,
#   'Omicron JN.1': 80.87,
#   'Other': 7.15},
#  '2024-02-05': {'Omicron BA.2': 3.49,
#   'Other': 7.11,
#   'Omicron JN.1': 79.25,
#   'Omicron BA.2.86': 6.51,
#   'Omicron XBB': 3.73},
#  '2024-02-12': {'Omicron BA.2.86': 5.92,
#   'Omicron JN.1': 82.57,
#   'Other': 5.92,
#   'Omicron BA.5': 0.16,
#   'Omicron XBB': 2.8,
#   'Omicron BA.2': 2.63},
#  '2024-02-19': {'Omicron XBB': 1.68,
#   'Omicron BA.2': 3.08,
#   'Omicron JN.1': 83.19,
#   'Omicron BA.2.86': 3.64,
#   'Other': 8.4},
#  '2024-02-26': {'Omicron XBB': 1.12,
#   'Omicron BA.5': 0.37,
#   'Omicron JN.1': 86.62,
#   'Omicron BA.2.86': 5.2,
#   'Omicron BA.2': 1.49,
#   'Other': 5.2},
#  '2024-03-04': {'Omicron BA.2': 1.22,
#   'Omicron XBB': 1.95,
#   'Omicron BA.2.86': 2.43,
#   'Omicron JN.1': 88.32,
#   'Other': 5.84,
#   'Omicron BA.1': 0.24},
#  '2024-03-11': {'Omicron XBB': 0.66,
#   'Omicron JN.1': 92.95,
#   'Other': 3.74,
#   'Omicron BA.2': 1.1,
#   'Omicron BA.2.86': 1.54},
#  '2024-03-18': {'Omicron JN.1': 92.09,
#   'Omicron XBB': 0.63,
#   'Omicron BA.2.86': 1.9,
#   'Other': 3.8,
#   'Omicron BA.2': 1.58},
#  '2024-03-25': {'Omicron BA.2': 0.63,
#   'Other': 7.59,
#   'Omicron JN.1': 89.24,
#   'Omicron BA.2.86': 2.53},
#  '2024-04-01': {'Omicron JN.1': 83.33, 'Omicron BA.2.86': 8.33, 'Other': 8.33},
#  '2024-04-08': {'Omicron XBB': 100.0},
#  '2024-04-15': {'Omicron XBB': 100.0},
#  '2024-05-06': {'Omicron JN.1': 100.0}}

# %% [markdown]
# Extracting the dates works as above. Notice that the dates are at least one week apart, as this is a weekly metric; in fact, they are all Mondays.

# %%
dates=list(data.keys())
dates.sort()
dates
# Out:
# ['2021-01-04',
#  '2021-01-11',
#  '2021-01-18',
#  '2021-01-25',
#  '2021-02-01',
#  '2021-02-08',
#  '2021-02-15',
#  '2021-02-22',
#  '2021-03-01',
#  '2021-03-08',
#  '2021-03-15',
#  '2021-03-22',
#  '2021-03-29',
#  '2021-04-05',
#  '2021-04-12',
#  '2021-04-19',
#  '2021-04-26',
#  '2021-05-03',
#  '2021-05-10',
#  '2021-05-17',
#  '2021-05-24',
#  '2021-05-31',
#  '2021-06-07',
#  '2021-06-14',
#  '2021-06-21',
#  '2021-06-28',
#  '2021-07-05',
#  '2021-07-12',
#  '2021-07-19',
#  '2021-07-26',
#  '2021-08-02',
#  '2021-08-09',
#  '2021-08-16',
#  '2021-08-23',
#  '2021-08-30',
#  '2021-09-06',
#  '2021-09-13',
#  '2021-09-20',
#  '2021-09-27',
#  '2021-10-04',
#  '2021-10-11',
#  '2021-10-18',
#  '2021-10-25',
#  '2021-11-01',
#  '2021-11-08',
#  '2021-11-15',
#  '2021-11-22',
#  '2021-11-29',
#  '2021-12-06',
#  '2021-12-13',
#  '2021-12-20',
#  '2021-12-27',
#  '2022-01-03',
#  '2022-01-10',
#  '2022-01-17',
#  '2022-01-24',
#  '2022-01-31',
#  '2022-02-07',
#  '2022-02-14',
#  '2022-02-21',
#  '2022-02-28',
#  '2022-03-07',
#  '2022-03-14',
#  '2022-03-21',
#  '2022-03-28',
#  '2022-04-04',
#  '2022-04-11',
#  '2022-04-18',
#  '2022-04-25',
#  '2022-05-02',
#  '2022-05-09',
#  '2022-05-16',
#  '2022-05-23',
#  '2022-05-30',
#  '2022-06-06',
#  '2022-06-13',
#  '2022-06-20',
#  '2022-06-27',
#  '2022-07-04',
#  '2022-07-11',
#  '2022-07-18',
#  '2022-07-25',
#  '2022-08-01',
#  '2022-08-08',
#  '2022-08-15',
#  '2022-08-22',
#  '2022-08-29',
#  '2022-09-05',
#  '2022-09-12',
#  '2022-09-19',
#  '2022-09-26',
#  '2022-10-03',
#  '2022-10-10',
#  '2022-10-17',
#  '2022-10-24',
#  '2022-10-31',
#  '2022-11-07',
#  '2022-11-14',
#  '2022-11-21',
#  '2022-11-28',
#  '2022-12-05',
#  '2022-12-12',
#  '2022-12-19',
#  '2022-12-26',
#  '2023-01-02',
#  '2023-01-09',
#  '2023-01-16',
#  '2023-01-23',
#  '2023-01-30',
#  '2023-02-06',
#  '2023-02-13',
#  '2023-02-20',
#  '2023-02-27',
#  '2023-03-06',
#  '2023-03-13',
#  '2023-03-20',
#  '2023-03-27',
#  '2023-04-03',
#  '2023-04-10',
#  '2023-04-17',
#  '2023-04-24',
#  '2023-05-01',
#  '2023-05-08',
#  '2023-05-15',
#  '2023-05-22',
#  '2023-05-29',
#  '2023-06-05',
#  '2023-06-12',
#  '2023-06-19',
#  '2023-06-26',
#  '2023-07-03',
#  '2023-07-10',
#  '2023-07-17',
#  '2023-07-24',
#  '2023-07-31',
#  '2023-08-07',
#  '2023-08-14',
#  '2023-08-21',
#  '2023-08-28',
#  '2023-09-04',
#  '2023-09-11',
#  '2023-09-18',
#  '2023-09-25',
#  '2023-10-02',
#  '2023-10-09',
#  '2023-10-16',
#  '2023-10-23',
#  '2023-10-30',
#  '2023-11-06',
#  '2023-11-13',
#  '2023-11-20',
#  '2023-11-27',
#  '2023-12-04',
#  '2023-12-11',
#  '2023-12-18',
#  '2023-12-25',
#  '2024-01-01',
#  '2024-01-08',
#  '2024-01-15',
#  '2024-01-22',
#  '2024-01-29',
#  '2024-02-05',
#  '2024-02-12',
#  '2024-02-19',
#  '2024-02-26',
#  '2024-03-04',
#  '2024-03-11',
#  '2024-03-18',
#  '2024-03-25',
#  '2024-04-01',
#  '2024-04-08',
#  '2024-04-15',
#  '2024-05-06']

# %%
startdate=parse_date(dates[0])
enddate=parse_date(dates[-1])
print (startdate, ' to ', enddate)
# Out:
# 2021-01-04 00:00:00  to  2024-05-06 00:00:00

# %% [markdown]
# Finding the columns is a bit more complicated, as we do not know their names and they do not all appear at the same time:

# %%
variants=[]
for entry in data.values():
    for var in entry.keys():
        if var not in variants:
            variants.append(var)
variants.sort()
print(variants)
# Out:
# ['Alpha', 'Delta', 'Omicron BA.1', 'Omicron BA.2', 'Omicron BA.2.75', 'Omicron BA.2.86', 'Omicron BA.4', 'Omicron BA.5', 'Omicron JN.1', 'Omicron XBB', 'Other']

# %% [markdown]
# We are finally ready to define our ```DataFrame```. We use a date range as an *index*, but this time we have to create with a weekly spacing. The sorted variants will be the columns.

# %%
# W-MON is "weekly on Mondays"
index=pd.date_range(startdate, enddate, freq='W-MON')
lineagedf=pd.DataFrame(index=index, columns=variants)
lineagedf
# Out:
#            Alpha Delta Omicron BA.1 Omicron BA.2 Omicron BA.2.75  \
# 2021-01-04   NaN   NaN          NaN          NaN             NaN
# 2021-01-11   NaN   NaN          NaN          NaN             NaN
# 2021-01-18   NaN   NaN          NaN          NaN             NaN
# 2021-01-25   NaN   NaN          NaN          NaN             NaN
# 2021-02-01   NaN   NaN          NaN          NaN             NaN
# ...          ...   ...          ...          ...             ...
# 2024-04-08   NaN   NaN          NaN          NaN             NaN
# 2024-04-15   NaN   NaN          NaN          NaN             NaN
# 2024-04-22   NaN   NaN          NaN          NaN             NaN
# 2024-04-29   NaN   NaN          NaN          NaN             NaN
# 2024-05-06   NaN   NaN          NaN          NaN             NaN
#
#            Omicron BA.2.86 Omicron BA.4 Omicron BA.5 Omicron JN.1 Omicron XBB  \
# 2021-01-04             NaN          NaN          NaN          NaN         NaN
# 2021-01-11             NaN          NaN          NaN          NaN         NaN
# 2021-01-18             NaN          NaN          NaN          NaN         NaN
# 2021-01-25             NaN          NaN          NaN          NaN         NaN
# 2021-02-01             NaN          NaN          NaN          NaN         NaN
# ...                    ...          ...          ...          ...         ...
# 2024-04-08             NaN          NaN          NaN          NaN         NaN
# 2024-04-15             NaN          NaN          NaN          NaN         NaN
# 2024-04-22             NaN          NaN          NaN          NaN         NaN
# 2024-04-29             NaN          NaN          NaN          NaN         NaN
# 2024-05-06             NaN          NaN          NaN          NaN         NaN
#
#            Other
# 2021-01-04   NaN
# 2021-01-11   NaN
# 2021-01-18   NaN
# 2021-01-25   NaN
# 2021-02-01   NaN
# ...          ...
# 2024-04-08   NaN
# 2024-04-15   NaN
# 2024-04-22   NaN
# 2024-04-29   NaN
# 2024-05-06   NaN
#
# [175 rows x 11 columns]

# %% [markdown]
# Filling in ```lineagedf``` is only a matter of looping over the dates and filling in the columns with the corresponding values.

# %%
for date, entry in data.items(): # each entry is a dic with some variants and values
    pd_date=parse_date(date) # convert to Pandas format
    for column in entry.keys(): # the variants
        # this is the way you access a specific location in the dataframe - use .loc
        # and put index,column in a single set of [ ]
        lineagedf.loc[date, column]=entry[column]

# fill in any remaining "holes" due to missing dates and variants
lineagedf.fillna(0.0, inplace=True)
# adjust types of columns filled in
lineagedf.infer_objects(copy=False)
            
lineagedf
# Out:
# /tmp/ipykernel_414/3400354542.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   lineagedf.fillna(0.0, inplace=True)
#             Alpha  Delta  Omicron BA.1  Omicron BA.2  Omicron BA.2.75  \
# 2021-01-04  81.59   0.03          0.22          0.00              0.0
# 2021-01-11  83.97   0.02          0.09          0.01              0.0
# 2021-01-18  88.68   0.04          0.02          0.00              0.0
# 2021-01-25  93.54   0.02          0.01          0.00              0.0
# 2021-02-01  95.18   0.01          0.04          0.00              0.0
# ...           ...    ...           ...           ...              ...
# 2024-04-08   0.00   0.00          0.00          0.00              0.0
# 2024-04-15   0.00   0.00          0.00          0.00              0.0
# 2024-04-22   0.00   0.00          0.00          0.00              0.0
# 2024-04-29   0.00   0.00          0.00          0.00              0.0
# 2024-05-06   0.00   0.00          0.00          0.00              0.0
#
#             Omicron BA.2.86  Omicron BA.4  Omicron BA.5  Omicron JN.1  \
# 2021-01-04              0.0           0.0          0.01           0.0
# 2021-01-11              0.0           0.0          0.00           0.0
# 2021-01-18              0.0           0.0          0.00           0.0
# 2021-01-25              0.0           0.0          0.01           0.0
# 2021-02-01              0.0           0.0          0.01           0.0
# ...                     ...           ...           ...           ...
# 2024-04-08              0.0           0.0          0.00           0.0
# 2024-04-15              0.0           0.0          0.00           0.0
# 2024-04-22              0.0           0.0          0.00           0.0
# 2024-04-29              0.0           0.0          0.00           0.0
# 2024-05-06              0.0           0.0          0.00         100.0
#
#             Omicron XBB  Other
# 2021-01-04          0.0  18.15
# 2021-01-11          0.0  15.92
# 2021-01-18          0.0  11.26
# 2021-01-25          0.0   6.42
# 2021-02-01          0.0   4.77
# ...                 ...    ...
# 2024-04-08        100.0   0.00
# 2024-04-15        100.0   0.00
# 2024-04-22          0.0   0.00
# 2024-04-29          0.0   0.00
# 2024-05-06          0.0   0.00
#
# [175 rows x 11 columns]

# %% [markdown]
# ### Plotting

# %% [markdown]
# We plot the data as a multiple stacked bar plot, aggregated by quarter. Each bar has the same meaning as a pie chart, representing proportions, and we have a series them arranged by date. For this and fancier bar plots (and other plots), see the excellent [book](https://link.springer.com/book/10.1007/978-3-031-57051-3) on data visualisation by F. Bianconi. This [tutorial](https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/) is also useful.
#
# To begin with, we group the dataset by quarters by averaging, in order to reduce the amount of data and at the same time deal with missing data:

# %%
# 1Q means "by quarter"; compute the average row
quarterly= lineagedf.groupby(pd.Grouper(freq='1QE')).mean() 
# since some data are missing, the sum across an average row may be less than one
totals=quarterly.sum(axis=1) # sum over the rows
# make sure it's all normalised to 100
quarterly=quarterly.div(totals, axis=0)*100 # divide the columns by the totals
# reverse the rows for the graph, so older dates will be on top
quarterly = quarterly[::-1]

# %% [markdown]
# Plotting is now relatively straightforward:

# %%
# we need a colormap with more than 11 colours 
ax=quarterly.plot(kind='barh', stacked=True,cmap='tab20')
ax.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
# format the dates nicely
ax.set_yticklabels(quarterly.index.strftime('%Y-%m-%d'))
ax.set_title('Lineage prevalence by quarter ending');

# %% [markdown]
# ## How to get ~~yourself~~ your data into a pickle (file)

# %% [markdown]
# In the actual dashboard, at this point, there is no need to save the dataframes - you can just add interactive controls to the graphs as you plot them. While developing, however, we want to save the wrangled data in order to be able to experiment with the controls. Pandas luckily makes it easy by providing a method that saves a ```DataFrame``` to a "pickle" file. This is based on the ```pickle``` [library](https://docs.python.org/3/library/pickle.html), that however is imported by ```pandas```, so you do not need to import it yourself. While JSON is a standard format that is language-independent, a *pickle* file is Python-specific. This format is thus more flexible, allowing the [serialisation](https://en.wikipedia.org/wiki/Serialization) of a broader range of Python objects; however, it is less portable.

# %%
# pandas makes saving to a pickle file dead easy:
timeseriesdf.to_pickle("timeseriesdf.pkl")
lineagedf.to_pickle("lineagedf.pkl")

# %% [markdown]
# ## Your turn
#
# Load the data you saved in the JSON files, munge it, turn it into a ```DataFrame``` and display it; then save your ```DataFrame``` to a *pickle* file. In the next notebook, when we will show you how to add interactive controls to your graphs.

# %% [markdown]
# **(C) 2020,2024 Fabrizio Smeraldi** ([f.smeraldi@qmul.ac.uk](mailto:f.smeraldi@qmul.ac.uk) - [web](http://www.eecs.qmul.ac.uk/~fabri/)). This notebook is released under the [GNU GPLv3.0 or later](https://www.gnu.org/licenses/).
